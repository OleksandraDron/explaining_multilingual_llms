# %%
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from itertools import combinations
from scipy.spatial.distance import cosine
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("data/English_evaluation.csv")

premise = df.Sentence1
hypothesis = df.Sentence2
label = df.gold_label
explanation = df.Generated_Explanation_EN


model_name = "roberta-large-mnli"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForSequenceClassification.from_pretrained(model_name)

model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
print(device)
# Out:
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# cuda

# %%
premises = []
hypotheses = []
labels = []
explanations = []
predicted_labels = []
prediction_confidence = []
Faith_score = []
Density_score =[]
Token_recall = []

# %%
#masked predictions
def get_prob(premise,hypothesis,mask_positions=[]):
    inputs = tokenizer(premise,hypothesis, return_tensors="pt")

    if mask_positions:
        for pos in mask_positions:
            inputs['input_ids'][0][pos] = tokenizer.mask_token_id
            
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.softmax(outputs.logits,dim=1) #convert to prob
    return probs[0].cpu().numpy()

# %%
#masking 
def shap(premise,hypothesis, target_label):
     
    inputs = tokenizer(premise, hypothesis, return_tensors="pt")
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])

    base_prob = get_prob(premise,hypothesis)[target_label]

    contributions = {}

    for i, token in enumerate(tokens):
        # Skip sPECIAL TOKENS 
        if token in ['<s>', '</s>', '<pad>']:
            contributions[i] = 0.0
            continue
    
        prob_without = get_prob(premise,hypothesis, mask_positions=[i])[target_label]

        contribution = base_prob - prob_without
        contributions[i] = contribution

        print(f"Token {i:2d} '{token:15s}': {contribution:+.4f}")

    return contributions,tokens

# %%
for index, row in df.iterrows():
    premise = row['Sentence1']
    hypothesis = row['Sentence2']
    label = row['gold_label']
    explanation = row['Generated_Explanation_EN']

    premises.append(premise)
    hypotheses.append(hypothesis)
    labels.append(label)
    explanations.append(explanation)

    
    
    #base prediction no mask
    base_probs = get_prob(premise,hypothesis)
    predicted_label = np.argmax(base_probs)
    label_names = ["contradiction", "neutral", "entailment"]

    
    predicted_labels.append(predicted_label)
    prediction_confidence.append(base_probs[predicted_label])

    contrib_pred, tokens = shap(premise,hypothesis,predicted_label)
    
    #normalize
    total = sum(abs(v) for v in contrib_pred.values())
    contrib_pred_norm = {k: v/total for k, v in contrib_pred.items()}

    
    sorted_tokens = sorted(contrib_pred_norm.items(), key=lambda x: abs(x[1]), reverse=True)[:5]

    top_5 = []

    for idx, contrib in sorted_tokens:
        if contrib > 0:
            top_5.append((idx,contrib))
        if len(top_5) == 5:
            break
    contrib_sum = sum(contrib for idx,contrib in top_5)
    

    for idx, contrib in sorted_tokens:
    
        print(f"  {tokens[idx]:15s}: {contrib:+.4f}")

        
    expl_tokens = tokenizer.tokenize(explanation)
    print(expl_tokens)

    top_tokens_in_exp =[]
    for idx, contrib in top_5:
        token = tokens[idx]
        if token in expl_tokens:
            top_tokens_in_exp.append((token, contrib))

    for token, contrib in top_tokens_in_exp:
        print(f"  {token:15s}: {contrib:+.4f}")

    total_contrib_in_exp = sum(contrib for token, contrib in top_tokens_in_exp)

    if contrib_sum > 0:
        faithfulness_score = total_contrib_in_exp / contrib_sum
    else:
        faithfulness_score = 0.0

    Faith_score.append(faithfulness_score)

    token_recall = len(top_tokens_in_exp) / len(top_5) if len(top_5) > 0 else 0.0
    Token_recall.append(token_recall)

    density = total_contrib_in_exp / len(expl_tokens) if len(expl_tokens) >0 else 0.0
    Density_score.append(density)
    

# Save the Results
df_results = pd.DataFrame({
    "premise": premises,
    "hypothesis": hypotheses,
    "label": labels,
    "explanation": explanations,
    "predicted_label": predicted_labels,
    "prediction_confidence": prediction_confidence,
    "Faith_score": Faith_score,
    "Density_score": Density_score,
    "Token_recall": Token_recall
})

df_results.to_csv("data/Results.csv", index=False)
print("Done! CSV saved with results.")
# Out:
# Token  1 'A              ': +0.0001
# Token  2 'Ġwoman         ': +0.0001
# Token  3 'Ġin            ': +0.0001
# Token  4 'Ġa             ': -0.0000
# Token  5 'Ġblue          ': +0.6329
# Token  6 'Ġa             ': +0.0001
# Token  7 'pron           ': +0.0005
# Token  8 'Ġcooking       ': +0.0000
# Token  9 'Ġin            ': +0.0000
# Token 10 'Ġa             ': +0.0001
# Token 11 'Ġkitchen       ': -0.0001
# Token 12 '.              ': -0.0001
# Token 15 'A              ': +0.0001
# Token 16 'Ġwoman         ': +0.0003
# Token 17 'Ġin            ': +0.0002
# Token 18 'Ġa             ': +0.0005
# Token 19 'Ġpink          ': +0.6386
# Token 20 'Ġa             ': -0.0000
# Token 21 'pron           ': +0.0002
# Token 22 'Ġsitting       ': +0.0001
# Token 23 'Ġin            ': +0.0001
# Token 24 'Ġa             ': -0.0001
# Token 25 'Ġkitchen       ': -0.0000
# Token 26 '.              ': -0.0001
#   Ġpink          : +0.5011
#   Ġblue          : +0.4966
#   pron           : +0.0004
#   Ġa             : +0.0004
#   Ġwoman         : +0.0002
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġwoman', 'Ġis', 'Ġwearing', 'Ġa', 'Ġblue', 'Ġa', 'pron', 'Ġand', 'Ġis', 'Ġactively', 'Ġcooking', ',', 'Ġwhile', 'Ġthe', 'Ġhypothesis', 'Ġdescribes', 'Ġher', 'Ġwearing', 'Ġa', 'Ġpink', 'Ġa', 'pron', 'Ġand', 'Ġsitting', '.', 'ĠThese', 'Ġare', 'Ġconflicting', 'Ġdescriptions', 'Ġof', 'Ġboth', 'Ġthe', 'Ġa', 'pron', 'Ġcolor', 'Ġand', 'Ġthe', 'Ġwoman', "'s", 'Ġactivity', ',', 'Ġmaking', 'Ġthe', 'Ġstatements', 'Ġmutually', 'Ġexclusive', '.']
#   Ġpink          : +0.5011
#   Ġblue          : +0.4966
#   pron           : +0.0004
#   Ġa             : +0.0004
#   Ġwoman         : +0.0002
# Token  1 'This           ': -0.0943
# Token  2 'Ġyoung         ': -0.0048
# Token  3 'Ġman           ': +0.0728
# Token  4 'Ġsmiles        ': -0.0354
# Token  5 'Ġas            ': +0.1940
# Token  6 'Ġhe            ': +0.0305
# Token  7 'Ġdiscovers     ': +0.6079
# Token  8 'Ġa             ': +0.1474
# Token  9 'Ġhors          ': +0.0468
# Token 10 'esh            ': +0.0464
# Token 11 'oe             ': +0.1434
# Token 12 'Ġcrab          ': +0.5417
# Token 13 'Ġin            ': +0.3272
# Token 14 'Ġthe           ': +0.3548
# Token 15 'Ġsand          ': +0.2004
# Token 16 '.              ': -0.0121
# Token 19 'The            ': -0.1312
# Token 20 'Ġyoung         ': -0.0379
# Token 21 'Ġman           ': -0.0194
# Token 22 'Ġis            ': -0.2142
# Token 23 'Ġat            ': +0.2698
# Token 24 'Ġschool        ': -0.0057
# Token 25 'Ġtaking        ': +0.3786
# Token 26 'Ġa             ': -0.0237
# Token 27 'Ġmath          ': +0.3201
# Token 28 'Ġtest          ': +0.2075
# Token 29 '.              ': -0.0792
#   Ġdiscovers     : +0.1337
#   Ġcrab          : +0.1191
#   Ġtaking        : +0.0832
#   Ġthe           : +0.0780
#   Ġin            : +0.0719
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġthe', 'Ġyoung', 'Ġman', 'Ġdiscovering', 'Ġa', 'Ġhors', 'esh', 'oe', 'Ġcrab', 'Ġin', 'Ġsand', ',', 'Ġwhich', 'Ġtypically', 'Ġoccurs', 'Ġin', 'Ġa', 'Ġbeach', 'Ġor', 'Ġcoastal', 'Ġenvironment', '.', 'ĠTaking', 'Ġa', 'Ġmath', 'Ġtest', 'Ġat', 'Ġschool', 'Ġis', 'Ġan', 'Ġindoor', 'Ġacademic', 'Ġactivity', 'Ġthat', 'Ġcannot', 'Ġoccur', 'Ġsimultaneously', 'Ġwith', 'Ġexploring', 'Ġa', 'Ġbeach', '.', 'ĠThese', 'Ġtwo', 'Ġscenarios', 'Ġinvolve', 'Ġincompatible', 'Ġlocations', 'Ġand', 'Ġactivities', '.']
#   Ġcrab          : +0.1191
#   Ġthe           : +0.0780
#   Ġin            : +0.0719
# Token  1 'Three          ': +0.0010
# Token  2 'Ġyoung         ': +0.0005
# Token  3 'Ġboys          ': +0.9963
# Token  4 'Ġplaying       ': +0.0002
# Token  5 'Ġwith          ': +0.0001
# Token  6 'Ġthe           ': +0.0002
# Token  7 'Ġmud           ': +0.0012
# Token  8 'Ġon            ': +0.0001
# Token  9 'Ġa             ': +0.0001
# Token 10 'Ġbeach         ': -0.0001
# Token 11 '.              ': +0.0001
# Token 14 'Three          ': +0.0008
# Token 15 'Ġyoung         ': +0.0001
# Token 16 'Ġgirls         ': +0.9923
# Token 17 'Ġare           ': +0.0001
# Token 18 'Ġat            ': -0.0001
# Token 19 'Ġthe           ': +0.0001
# Token 20 'Ġbeach         ': -0.0003
# Token 21 '.              ': -0.0000
#   Ġboys          : +0.4997
#   Ġgirls         : +0.4977
#   Ġmud           : +0.0006
#   Three          : +0.0005
#   Three          : +0.0004
# ['The', 'Ġpremise', 'Ġspecifies', 'Ġthe', 'Ġindividuals', 'Ġare', 'Ġ"', 'young', 'Ġboys', ',"', 'Ġwhile', 'Ġthe', 'Ġhypothesis', 'Ġrefers', 'Ġto', 'Ġ"', 'young', 'Ġgirls', '."', 'ĠSince', 'Ġboys', 'Ġand', 'Ġgirls', 'Ġare', 'Ġdistinct', 'Ġcategories', ',', 'Ġthe', 'Ġhypothesis', 'Ġdirectly', 'Ġcontradicts', 'Ġthe', 'Ġgender', 'Ġinformation', 'Ġprovided', 'Ġin', 'Ġthe', 'Ġpremise', '.']
#   Ġboys          : +0.4997
#   Ġgirls         : +0.4977
# Token  1 'A              ': +0.0001
# Token  2 'Ġlock          ': +0.0014
# Token  3 'Ġbox           ': +0.0109
# Token  4 'Ġon            ': -0.0002
# Token  5 'Ġa             ': +0.0001
# Token  6 'Ġpole          ': -0.0006
# Token  7 'Ġwith          ': -0.0003
# Token  8 'Ġthe           ': +0.0004
# Token  9 'Ġkeys          ': +0.0199
# Token 10 'Ġin            ': -0.0002
# Token 11 'Ġit            ': +0.0002
# Token 12 '.              ': -0.0004
# Token 15 'A              ': +0.0010
# Token 16 'Ġblue          ': +0.6994
# Token 17 'Ġlock          ': +0.0018
# Token 18 'Ġbox           ': +0.0004
# Token 19 'Ġ              ': -0.0004
# Token 20 'Ġattached      ': +0.0017
# Token 21 'Ġto            ': +0.0013
# Token 22 'Ġthe           ': +0.0007
# Token 23 'Ġside          ': +0.0001
# Token 24 'Ġof            ': +0.0001
# Token 25 'Ġthe           ': +0.0006
# Token 26 'Ġhouse         ': +0.0008
# Token 27 '.              ': -0.0004
#   Ġblue          : +0.9407
#   Ġkeys          : +0.0268
#   Ġbox           : +0.0146
#   Ġlock          : +0.0024
#   Ġattached      : +0.0023
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġlock', 'Ġbox', 'Ġon', 'Ġa', 'Ġpole', ',', 'Ġwhile', 'Ġthe', 'Ġhypothesis', 'Ġdescribes', 'Ġone', 'Ġattached', 'Ġto', 'Ġthe', 'Ġside', 'Ġof', 'Ġa', 'Ġhouse', '.', 'ĠThese', 'Ġare', 'Ġtwo', 'Ġdifferent', 'Ġlocations', 'Ġthat', 'Ġcannot', 'Ġboth', 'Ġbe', 'Ġtrue', 'Ġfor', 'Ġthe', 'Ġsame', 'Ġlock', 'Ġbox', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġstatements', 'Ġcontradict', 'Ġeach', 'Ġother', '.']
#   Ġbox           : +0.0146
#   Ġlock          : +0.0024
#   Ġattached      : +0.0023
# Token  1 'A              ': +0.0038
# Token  2 'Ġman           ': +0.0054
# Token  3 'Ġp             ': -0.0023
# Token  4 'ours           ': -0.0031
# Token  5 'Ġwater         ': +0.0388
# Token  6 'Ġon            ': +0.0025
# Token  7 'Ġplants        ': +0.0540
# Token  8 'Ġin            ': +0.0039
# Token  9 'Ġa             ': +0.0005
# Token 10 'Ġvast          ': +0.0017
# Token 11 'Ġfield         ': +0.0074
# Token 12 'Ġof            ': +0.0018
# Token 13 'Ġsmall         ': +0.0029
# Token 14 'Ġplants        ': +0.0041
# Token 15 '.              ': +0.0062
# Token 18 'A              ': +0.0124
# Token 19 'Ġman           ': -0.0013
# Token 20 'Ġwaters        ': +0.1278
# Token 21 'Ġplants        ': +0.0115
#   Ġwaters        : +0.4385
#   Ġplants        : +0.1851
#   Ġwater         : +0.1333
#   A              : +0.0424
#   Ġplants        : +0.0394
# ['The', 'Ġpremise', 'Ġstates', 'Ġthat', 'Ġa', 'Ġman', 'Ġp', 'ours', 'Ġwater', 'Ġon', 'Ġplants', 'Ġin', 'Ġa', 'Ġfield', ',', 'Ġwhich', 'Ġdirectly', 'Ġdescribes', 'Ġthe', 'Ġaction', 'Ġof', 'Ġwatering', 'Ġplants', '.', 'ĠWater', 'ing', 'Ġplants', 'Ġinvolves', 'Ġapplying', 'Ġwater', 'Ġto', 'Ġthem', ',', 'Ġand', 'Ġpouring', 'Ġwater', 'Ġis', 'Ġa', 'Ġcommon', 'Ġmethod', 'Ġof', 'Ġdoing', 'Ġso', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġlogically', 'Ġentails', 'Ġthe', 'Ġhypothesis', '.']
#   Ġplants        : +0.1851
#   Ġwater         : +0.1333
#   Ġplants        : +0.0394
# Token  1 'Dark           ': +0.0120
# Token  2 'Ġnightclub     ': +0.2376
# Token  3 'Ġwith          ': +0.0409
# Token  4 'Ġchairs        ': +0.2766
# Token  5 '.              ': +0.0326
# Token  8 'The            ': +0.0247
# Token  9 'Ġboun          ': -0.1001
# Token 10 'cers           ': +0.0151
# Token 11 'Ġescorted      ': +0.2326
# Token 12 'Ġa             ': -0.1015
# Token 13 'Ġbellig        ': +0.0122
# Token 14 'erent          ': -0.0300
# Token 15 'Ġpatron        ': -0.0542
# Token 16 'Ġfrom          ': +0.0360
# Token 17 'Ġthe           ': +0.0271
# Token 18 'Ġbar           ': +0.0996
# Token 19 '.              ': +0.0047
#   Ġchairs        : +0.2068
#   Ġnightclub     : +0.1777
#   Ġescorted      : +0.1739
#   Ġa             : -0.0759
#   Ġboun          : -0.0748
# ['The', 'Ġpremise', 'Ġonly', 'Ġdescribes', 'Ġa', 'Ġnightclub', "'s", 'Ġlighting', 'Ġand', 'Ġfurniture', ',', 'Ġwith', 'Ġno', 'Ġmention', 'Ġof', 'Ġboun', 'cers', ',', 'Ġpatrons', ',', 'Ġor', 'Ġany', 'Ġevents', 'Ġoccurring', '.', 'ĠThe', 'Ġhypothesis', 'Ġintroduces', 'Ġspecific', 'Ġactions', 'Ġinvolving', 'Ġboun', 'cers', 'Ġand', 'Ġa', 'Ġpatron', ',', 'Ġwhich', 'Ġcannot', 'Ġbe', 'Ġlogically', 'Ġinferred', 'Ġfrom', 'Ġthe', 'Ġlimited', 'Ġinformation', 'Ġprovided', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġneither', 'Ġsupports', 'Ġnor', 'Ġimplies', 'Ġthe', 'Ġhypothesis', ',', 'Ġmaking', 'Ġthem', 'Ġcontradictory', 'Ġin', 'Ġcontent', '.']
#   Ġnightclub     : +0.1777
# Token  1 'A              ': -0.0001
# Token  2 'Ġyoung         ': +0.0000
# Token  3 'Ġwoman         ': -0.0003
# Token  4 'Ġsmiles        ': +0.0173
# Token  5 'Ġas            ': -0.0003
# Token  6 'Ġshe           ': -0.0008
# Token  7 'Ġshoots        ': +0.0018
# Token  8 'Ġa             ': -0.0003
# Token  9 'Ġgun           ': -0.0002
# Token 10 'Ġat            ': -0.0003
# Token 11 'Ġan            ': -0.0004
# Token 12 'Ġindoor        ': +0.0008
# Token 13 'Ġtarget        ': -0.0003
# Token 14 'Ġrange         ': -0.0003
# Token 15 ',              ': -0.0000
# Token 16 'Ġas            ': -0.0001
# Token 17 'Ġan            ': -0.0000
# Token 18 'Ġolder         ': +0.0003
# Token 19 'Ġman           ': +0.0005
# Token 20 'Ġlooks         ': -0.0004
# Token 21 'Ġon            ': +0.0000
# Token 22 'Ġm             ': -0.0000
# Token 23 'irth           ': +0.0000
# Token 24 'lessly         ': +0.0002
# Token 25 '.              ': +0.0058
# Token 28 'a              ': -0.0004
# Token 29 'Ġyoung         ': +0.0004
# Token 30 'Ġwoman         ': +0.0010
# Token 31 'Ġsmiles        ': +0.0125
# Token 32 'Ġas            ': -0.0001
# Token 33 'Ġshe           ': +0.0000
# Token 34 'Ġshoots        ': +0.0006
# Token 35 'Ġat            ': +0.0006
# Token 36 'Ġan            ': +0.0002
# Token 37 'Ġindoor        ': +0.0027
# Token 38 'Ġshooting      ': +0.0001
# Token 39 'Ġrange         ': +0.0031
#   Ġsmiles        : +0.3323
#   Ġsmiles        : +0.2391
#   .              : +0.1118
#   Ġrange         : +0.0595
#   Ġindoor        : +0.0526
# ['The', 'Ġpremise', 'Ġstates', 'Ġthat', 'Ġa', 'Ġyoung', 'Ġwoman', 'Ġsmiles', 'Ġwhile', 'Ġshooting', 'Ġa', 'Ġgun', 'Ġat', 'Ġan', 'Ġindoor', 'Ġtarget', 'Ġrange', ',', 'Ġwhich', 'Ġdirectly', 'Ġsupports', 'Ġthe', 'Ġhypothesis', 'Ġthat', 'Ġshe', 'Ġsmiles', 'Ġwhile', 'Ġshooting', 'Ġat', 'Ġan', 'Ġindoor', 'Ġshooting', 'Ġrange', '.', 'ĠThe', 'Ġpresence', 'Ġof', 'Ġthe', 'Ġolder', 'Ġman', 'Ġand', 'Ġhis', 'Ġexpression', 'Ġare', 'Ġadditional', 'Ġdetails', 'Ġnot', 'Ġrequired', 'Ġfor', 'Ġthe', 'Ġhypothesis', 'Ġto', 'Ġbe', 'Ġtrue', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġlogically', 'Ġentails', 'Ġthe', 'Ġhypothesis', '.']
#   Ġsmiles        : +0.3323
#   Ġsmiles        : +0.2391
#   .              : +0.1118
#   Ġrange         : +0.0595
#   Ġindoor        : +0.0526
# Token  1 'A              ': -0.0000
# Token  2 'Ġman           ': +0.0000
# Token  3 'Ġwearing       ': -0.0000
# Token  4 'Ġa             ': +0.0001
# Token  5 'Ġmartial       ': -0.0006
# Token  6 'Ġarts          ': +0.0000
# Token  7 'Ġuniform       ': -0.0004
# Token  8 'Ġis            ': +0.0001
# Token  9 'Ġjumping       ': +0.0025
# Token 10 'Ġthrough       ': +0.0000
# Token 11 'Ġthe           ': -0.0000
# Token 12 'Ġair           ': -0.0004
# Token 13 '.              ': -0.0002
# Token 16 'The            ': +0.0001
# Token 17 'Ġman           ': +0.0004
# Token 18 'Ġleaps         ': +0.0017
# Token 19 'Ġthrough       ': +0.0004
# Token 20 'Ġthe           ': +0.0000
# Token 21 'Ġair           ': -0.0002
# Token 22 ',              ': -0.0005
# Token 23 'Ġwhilst        ': -0.0001
# Token 24 'Ġwearing       ': -0.0000
# Token 25 'Ġa             ': +0.0000
# Token 26 'Ġmartial       ': +0.0001
# Token 27 'Ġarts          ': +0.0002
# Token 28 'Ġuniform       ': +0.0007
# Token 29 '.              ': -0.0004
#   Ġjumping       : +0.2724
#   Ġleaps         : +0.1777
#   Ġuniform       : +0.0800
#   Ġmartial       : -0.0666
#   ,              : -0.0565
# ['The', 'Ġpremise', 'Ġstates', 'Ġthat', 'Ġa', 'Ġman', 'Ġin', 'Ġa', 'Ġmartial', 'Ġarts', 'Ġuniform', 'Ġis', 'Ġjumping', 'Ġthrough', 'Ġthe', 'Ġair', ',', 'Ġand', 'Ġthe', 'Ġhypothesis', 'Ġdescribes', 'Ġthe', 'Ġsame', 'Ġaction', 'Ġof', 'Ġleaping', 'Ġthrough', 'Ġthe', 'Ġair', 'Ġwhile', 'Ġwearing', 'Ġthe', 'Ġuniform', '.', 'ĠSince', 'Ġ"', 'j', 'umping', '"', 'Ġand', 'Ġ"', 'le', 'aping', '"', 'Ġare', 'Ġsynonymous', 'Ġin', 'Ġthis', 'Ġcontext', ',', 'Ġthe', 'Ġpremise', 'Ġfully', 'Ġsupports', 'Ġthe', 'Ġhypothesis', '.']
#   Ġjumping       : +0.2724
#   Ġuniform       : +0.0800
# Token  1 'A              ': +0.0004
# Token  2 'Ġgirl          ': +0.0086
# Token  3 'Ġwearing       ': +0.0001
# Token  4 'Ġa             ': -0.0001
# Token  5 'Ġwhite         ': +0.0002
# Token  6 'Ġhood          ': +0.0003
# Token  7 'ed             ': -0.0001
# Token  8 'Ġsweater       ': -0.0001
# Token  9 'Ġis            ': +0.0001
# Token 10 'Ġsitting       ': -0.0002
# Token 11 'Ġon            ': -0.0000
# Token 12 'Ġthe           ': +0.0002
# Token 13 'Ġground        ': +0.0017
# Token 14 '.              ': +0.0000
# Token 17 'A              ': +0.0011
# Token 18 'Ġdog           ': +0.1219
# Token 19 'Ġis            ': +0.0002
# Token 20 'Ġsleeping      ': +0.0042
# Token 21 '.              ': +0.0000
#   Ġdog           : +0.8734
#   Ġgirl          : +0.0619
#   Ġsleeping      : +0.0303
#   Ġground        : +0.0125
#   A              : +0.0077
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġgirl', 'Ġsitting', 'Ġon', 'Ġthe', 'Ġground', 'Ġwearing', 'Ġa', 'Ġwhite', 'Ġhood', 'ed', 'Ġsweater', ',', 'Ġwith', 'Ġno', 'Ġmention', 'Ġof', 'Ġany', 'Ġdog', 'Ġpresent', '.', 'ĠSince', 'Ġthe', 'Ġhypothesis', 'Ġclaims', 'Ġa', 'Ġdog', 'Ġis', 'Ġsleeping', ',', 'Ġthis', 'Ġintroduces', 'Ġan', 'Ġentirely', 'Ġnew', 'Ġentity', 'Ġand', 'Ġactivity', 'Ġnot', 'Ġsupported', 'Ġby', 'Ġthe', 'Ġpremise', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġstatements', 'Ġcannot', 'Ġboth', 'Ġbe', 'Ġtrue', 'Ġsimultaneously', '.']
#   Ġdog           : +0.8734
#   Ġgirl          : +0.0619
#   Ġsleeping      : +0.0303
#   Ġground        : +0.0125
# Token  1 'A              ': -0.0004
# Token  2 'Ġbrun          ': +0.1498
# Token  3 'ette           ': -0.0030
# Token  4 'Ġwoman         ': -0.0028
# Token  5 'Ġin            ': +0.0018
# Token  6 'Ġa             ': +0.0013
# Token  7 'Ġblue          ': -0.0000
# Token  8 'Ġshirt         ': +0.0438
# Token  9 'Ġtoo           ': +0.0027
# Token 10 'Ġsmall         ': +0.0241
# Token 11 'Ġfor           ': +0.0015
# Token 12 'Ġher           ': +0.0018
# Token 13 'Ġstanding      ': +0.0003
# Token 14 'Ġbehind        ': +0.0017
# Token 15 'Ġcasually      ': -0.0006
# Token 16 '-              ': -0.0002
# Token 17 'd              ': +0.0003
# Token 18 'ressed         ': +0.0005
# Token 19 'Ġpeople        ': +0.0001
# Token 20 '.              ': +0.0054
# Token 23 'a              ': +0.0010
# Token 24 'Ġdark          ': -0.0002
# Token 25 'Ġha            ': +0.0009
# Token 26 'ired           ': +0.0157
# Token 27 'Ġwoman         ': +0.0010
# Token 28 'Ġstands        ': -0.0005
# Token 29 'Ġbehind        ': -0.0001
# Token 30 'Ġa             ': +0.0000
# Token 31 'Ġgroup         ': +0.0066
# Token 32 'Ġwearing       ': +0.0007
# Token 33 'Ġa             ': +0.0009
# Token 34 'Ġsmall         ': +0.0239
# Token 35 'Ġshirt         ': +0.0551
#   Ġbrun          : +0.4295
#   Ġshirt         : +0.1581
#   Ġshirt         : +0.1257
#   Ġsmall         : +0.0690
#   Ġsmall         : +0.0686
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġwoman', 'Ġis', 'Ġa', 'Ġbrun', 'ette', ',', 'Ġwhich', 'Ġmeans', 'Ġshe', 'Ġhas', 'Ġdark', 'Ġhair', ',', 'Ġand', 'Ġshe', 'Ġis', 'Ġwearing', 'Ġa', 'Ġblue', 'Ġshirt', 'Ġthat', 'Ġis', 'Ġtoo', 'Ġsmall', 'Ġfor', 'Ġher', '.', 'ĠSince', 'Ġshe', 'Ġis', 'Ġstanding', 'Ġbehind', 'Ġcasually', '-', 'd', 'ressed', 'Ġpeople', ',', 'Ġthis', 'Ġalign', 's', 'Ġwith', 'Ġthe', 'Ġhypothesis', 'Ġthat', 'Ġa', 'Ġdark', '-', 'haired', 'Ġwoman', 'Ġstands', 'Ġbehind', 'Ġa', 'Ġgroup', 'Ġwhile', 'Ġwearing', 'Ġa', 'Ġsmall', 'Ġshirt', '.']
#   Ġbrun          : +0.4295
#   Ġshirt         : +0.1581
#   Ġshirt         : +0.1257
#   Ġsmall         : +0.0690
#   Ġsmall         : +0.0686
# Token  1 'Old            ': -0.0649
# Token  2 'Ġwoman         ': +0.0889
# Token  3 'Ġwith          ': +0.1171
# Token  4 'Ġa             ': +0.0059
# Token  5 'Ġwhite         ': +0.2338
# Token  6 'Ġsweater       ': -0.0691
# Token  7 'Ġand           ': +0.0145
# Token  8 'Ġsh            ': -0.0076
# Token  9 'aw             ': +0.0282
# Token 10 'l              ': +0.0499
# Token 11 'Ġstanding      ': +0.1019
# Token 12 'Ġat            ': +0.0004
# Token 13 'Ġa             ': +0.0054
# Token 14 'Ġshopping      ': +0.0405
# Token 15 'Ġcenter        ': +0.0479
# Token 16 'Ġin            ': +0.0005
# Token 17 'ĠLondon        ': +0.0089
# Token 18 '.              ': +0.0006
# Token 21 'An             ': -0.0597
# Token 22 'Ġold           ': -0.0115
# Token 23 'Ġwoman         ': +0.0049
# Token 24 'Ġis            ': -0.0198
# Token 25 'Ġshopping      ': -0.0358
# Token 26 'Ġfor           ': +0.0312
# Token 27 'Ġa             ': -0.0250
# Token 28 'Ġnew           ': +0.1559
# Token 29 'Ġsweater       ': -0.0678
# Token 30 '.              ': -0.0235
#   Ġwhite         : +0.1770
#   Ġnew           : +0.1180
#   Ġwith          : +0.0886
#   Ġstanding      : +0.0771
#   Ġwoman         : +0.0673
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġthe', 'Ġwoman', 'Ġis', 'Ġstanding', 'Ġin', 'Ġa', 'Ġshopping', 'Ġcenter', ',', 'Ġbut', 'Ġit', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġthat', 'Ġshe', 'Ġis', 'Ġshopping', 'Ġor', 'Ġlooking', 'Ġfor', 'Ġa', 'Ġsweater', '.', 'ĠWhile', 'Ġshe', 'Ġis', 'Ġwearing', 'Ġa', 'Ġsweater', ',', 'Ġthere', 'Ġis', 'Ġno', 'Ġevidence', 'Ġthat', 'Ġshe', 'Ġis', 'Ġactively', 'Ġshopping', 'Ġfor', 'Ġa', 'Ġnew', 'Ġone', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġcannot', 'Ġbe', 'Ġconfirmed', 'Ġor', 'Ġcontradicted', 'Ġbased', 'Ġsolely', 'Ġon', 'Ġthe', 'Ġgiven', 'Ġinformation', '.']
#   Ġnew           : +0.1180
#   Ġstanding      : +0.0771
#   Ġwoman         : +0.0673
# Token  1 'The            ': +0.0152
# Token  2 'Ġgirl          ': -0.0176
# Token  3 'Ġon            ': -0.0158
# Token  4 'Ġthe           ': +0.0350
# Token  5 'Ġun            ': -0.0187
# Token  6 'icycle         ': +0.0302
# Token  7 'Ġreaches       ': +0.0213
# Token  8 'Ġout           ': -0.0365
# Token  9 'Ġfor           ': -0.0261
# Token 10 'Ġthe           ': -0.0055
# Token 11 'Ġchild         ': -0.0627
# Token 12 'Ġon            ': -0.0008
# Token 13 'Ġthe           ': +0.0007
# Token 14 'Ġsc            ': +0.0057
# Token 15 'ooter          ': +0.0098
# Token 16 '.              ': -0.0001
# Token 19 'road           ': +0.0369
# Token 20 'rage           ': -0.1064
# Token 21 'Ġtakes         ': -0.0238
# Token 22 'Ġplace         ': -0.0092
# Token 23 'Ġon            ': +0.0107
# Token 24 'Ġa             ': +0.0790
# Token 25 'Ġhighway       ': +0.1803
#   Ġhighway       : +0.2411
#   rage           : -0.1422
#   Ġa             : +0.1056
#   Ġchild         : -0.0839
#   road           : +0.0493
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġplayful', 'Ġinteraction', 'Ġbetween', 'Ġa', 'Ġgirl', 'Ġon', 'Ġa', 'Ġun', 'icycle', 'Ġand', 'Ġa', 'Ġchild', 'Ġon', 'Ġa', 'Ġsc', 'ooter', ',', 'Ġwhich', 'Ġsuggests', 'Ġa', 'Ġcasual', 'Ġor', 'Ġrecreational', 'Ġsetting', '.', 'ĠThe', 'Ġhypothesis', 'Ġdescribes', 'Ġroad', 'Ġrage', 'Ġoccurring', 'Ġon', 'Ġa', 'Ġhighway', ',', 'Ġwhich', 'Ġimplies', 'Ġaggressive', 'Ġdriving', 'Ġbehavior', 'Ġin', 'Ġa', 'Ġhigh', '-', 'speed', 'Ġtraffic', 'Ġenvironment', '.', 'ĠThese', 'Ġscenarios', 'Ġare', 'Ġfundamentally', 'Ġincompatible', 'Ġin', 'Ġtone', 'Ġand', 'Ġcontext', ',', 'Ġcreating', 'Ġa', 'Ġcontradiction', '.']
#   Ġhighway       : +0.2411
#   Ġa             : +0.1056
# Token  1 'A              ': +0.0069
# Token  2 'Ġman           ': +0.0008
# Token  3 'Ġin            ': +0.0037
# Token  4 'Ġa             ': +0.0020
# Token  5 'Ġbrown         ': +0.0076
# Token  6 'Ġshirt         ': +0.0033
# Token  7 'Ġplays         ': +0.3283
# Token  8 'Ġa             ': +0.0099
# Token  9 'Ġmusical       ': +0.0218
# Token 10 'Ġinstrument    ': -0.0016
# Token 11 'Ġwith          ': +0.0051
# Token 12 'Ġa             ': +0.0001
# Token 13 'Ġband          ': +0.2648
# Token 14 'Ġin            ': +0.0029
# Token 15 'Ġfront         ': -0.0031
# Token 16 'Ġof            ': +0.0011
# Token 17 'Ġa             ': +0.0034
# Token 18 'Ġcrowd         ': -0.0015
# Token 19 'Ġof            ': +0.0019
# Token 20 'Ġpeople        ': -0.0013
# Token 21 '.              ': -0.0044
# Token 24 'The            ': +0.0259
# Token 25 'Ġman           ': +0.0022
# Token 26 'Ġin            ': +0.0064
# Token 27 'Ġa             ': +0.0055
# Token 28 'Ġbrown         ': +0.0040
# Token 29 'Ġshirt         ': +0.0086
# Token 30 'Ġis            ': -0.0033
# Token 31 'Ġjuggling      ': +0.9738
# Token 32 'Ġin            ': -0.0017
# Token 33 'Ġfront         ': -0.0055
# Token 34 'Ġof            ': -0.0009
# Token 35 'Ġa             ': +0.0009
# Token 36 'Ġcrowd         ': -0.0033
# Token 37 'Ġof            ': -0.0019
# Token 38 'Ġpeople        ': -0.0061
# Token 39 '.              ': -0.0038
#   Ġjuggling      : +0.5631
#   Ġplays         : +0.1898
#   Ġband          : +0.1532
#   The            : +0.0150
#   Ġmusical       : +0.0126
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġman', 'Ġis', 'Ġplaying', 'Ġa', 'Ġmusical', 'Ġinstrument', 'Ġwith', 'Ġa', 'Ġband', ',', 'Ġwhich', 'Ġinvolves', 'Ġperforming', 'Ġmusic', '.', 'ĠJugg', 'ling', 'Ġis', 'Ġa', 'Ġdifferent', 'Ġphysical', 'Ġperformance', 'Ġthat', 'Ġdoes', 'Ġnot', 'Ġinvolve', 'Ġplaying', 'Ġan', 'Ġinstrument', '.', 'ĠSince', 'Ġthese', 'Ġare', 'Ġmutually', 'Ġexclusive', 'Ġactivities', ',', 'Ġthe', 'Ġhypothesis', 'Ġcontradicts', 'Ġthe', 'Ġpremise', '.']
#   Ġband          : +0.1532
#   The            : +0.0150
#   Ġmusical       : +0.0126
# Token  1 'A              ': +0.0280
# Token  2 'Ġtoddler       ': -0.1590
# Token  3 'Ġin            ': +0.0668
# Token  4 'Ġa             ': +0.0432
# Token  5 'Ġblue          ': +0.4391
# Token  6 'Ġshirt         ': +0.4108
# Token  7 'Ġwith          ': +0.0147
# Token  8 'Ġred           ': +0.1668
# Token  9 'Ġshorts        ': +0.1088
# Token 10 'Ġand           ': +0.0236
# Token 11 'Ġhat           ': -0.0055
# Token 12 'Ġlooks         ': -0.0466
# Token 13 'Ġout           ': +0.0034
# Token 14 'Ġfrom          ': -0.0341
# Token 15 'Ġbehind        ': -0.0378
# Token 16 'Ġa             ': -0.0297
# Token 17 'Ġf             ': -0.0106
# Token 18 'enced          ': -0.1020
# Token 19 'Ġin            ': -0.0412
# Token 20 'Ġarea          ': -0.0904
# Token 21 'Ġof            ': -0.0110
# Token 22 'Ġa             ': -0.0052
# Token 23 'Ġbrick         ': -0.0216
# Token 24 'Ġpatio         ': +0.0087
# Token 25 '.              ': +0.0304
# Token 28 'The            ': -0.0740
# Token 29 'Ġtoddler       ': -0.1216
# Token 30 'Ġis            ': +0.0212
# Token 31 'Ġwearing       ': +0.0222
# Token 32 'Ġa             ': +0.0339
# Token 33 'Ġblue          ': +0.3575
# Token 34 'Ġpol           ': +0.0826
# Token 35 'o              ': +0.1147
# Token 36 'Ġshirt         ': +0.0915
# Token 37 '.              ': +0.1438
#   Ġblue          : +0.1463
#   Ġshirt         : +0.1368
#   Ġblue          : +0.1191
#   Ġred           : +0.0556
#   Ġtoddler       : -0.0530
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġthe', 'Ġtoddler', 'Ġis', 'Ġwearing', 'Ġa', 'Ġblue', 'Ġshirt', 'Ġbut', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġthe', 'Ġstyle', 'Ġof', 'Ġthe', 'Ġshirt', '.', 'ĠA', 'Ġpol', 'o', 'Ġshirt', 'Ġis', 'Ġone', 'Ġpossible', 'Ġtype', 'Ġof', 'Ġblue', 'Ġshirt', ',', 'Ġbut', 'Ġthe', 'Ġpremise', 'Ġdoes', 'Ġnot', 'Ġprovide', 'Ġenough', 'Ġinformation', 'Ġto', 'Ġconfirm', 'Ġor', 'Ġdeny', 'Ġthis', 'Ġspecific', 'Ġdetail', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġrelationship', 'Ġbetween', 'Ġthe', 'Ġpremise', 'Ġand', 'Ġhypothesis', 'Ġis', 'Ġneither', 'Ġclearly', 'Ġsupported', 'Ġnor', 'Ġcontradicted', '.']
#   Ġblue          : +0.1463
#   Ġshirt         : +0.1368
#   Ġblue          : +0.1191
# Token  1 'Pink           ': +0.1223
# Token  2 'Ġsh            ': +0.0101
# Token  3 'irted          ': -0.0744
# Token  4 'Ġwoman         ': -0.0843
# Token  5 'Ġsleeping      ': -0.1855
# Token  6 'Ġin            ': +0.0582
# Token  7 'Ġa             ': +0.1995
# Token  8 'Ġcar           ': +0.7822
# Token  9 'Ġwith          ': -0.1379
# Token 10 'Ġblue          ': -0.1295
# Token 11 'Ġand           ': -0.0650
# Token 12 'Ġwhite         ': -0.1042
# Token 13 'Ġblanket       ': -0.1304
# Token 14 'Ġon            ': -0.0865
# Token 15 'Ġher           ': -0.0701
# Token 16 '.              ': -0.0045
# Token 19 'The            ': +0.2988
# Token 20 'Ġwomen         ': -0.1343
# Token 21 'Ġin            ': +0.4747
# Token 22 'Ġon            ': -0.0457
# Token 23 'Ġher           ': -0.0301
# Token 24 'Ġphone         ': +0.4791
# Token 25 'Ġin            ': -0.1006
# Token 26 'Ġthe           ': +0.0850
# Token 27 'Ġcar           ': +0.1071
# Token 28 '.              ': -0.0566
#   Ġcar           : +0.1928
#   Ġphone         : +0.1181
#   Ġin            : +0.1170
#   The            : +0.0737
#   Ġa             : +0.0492
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġwoman', 'Ġsleeping', 'Ġin', 'Ġa', 'Ġcar', ',', 'Ġwhich', 'Ġrequires', 'Ġher', 'Ġto', 'Ġbe', 'Ġunconscious', 'Ġand', 'Ġinactive', '.', 'ĠThe', 'Ġhypothesis', 'Ġclaims', 'Ġshe', 'Ġis', 'Ġusing', 'Ġher', 'Ġphone', ',', 'Ġwhich', 'Ġrequires', 'Ġher', 'Ġto', 'Ġbe', 'Ġawake', 'Ġand', 'Ġactively', 'Ġengaged', '.', 'ĠThese', 'Ġtwo', 'Ġstates', 'Ġcannot', 'Ġsimultaneously', 'Ġbe', 'Ġtrue', 'Ġfor', 'Ġthe', 'Ġsame', 'Ġperson', '.']
#   Ġcar           : +0.1928
#   Ġphone         : +0.1181
#   Ġin            : +0.1170
#   The            : +0.0737
#   Ġa             : +0.0492
# Token  1 'A              ': +0.0009
# Token  2 'Ġpair          ': +0.3240
# Token  3 'Ġof            ': -0.0007
# Token  4 'Ġblack         ': -0.0007
# Token  5 'Ġwomen         ': +0.3202
# Token  6 'Ġon            ': +0.0018
# Token  7 'Ġthe           ': -0.0007
# Token  8 'Ġstreet        ': +0.0018
# Token  9 'Ġwhere         ': +0.0004
# Token 10 'Ġone           ': +0.0065
# Token 11 'Ġof            ': +0.0011
# Token 12 'Ġthem          ': +0.0008
# Token 13 'Ġis            ': +0.0014
# Token 14 'Ġwalking       ': +0.0053
# Token 15 'Ġpast          ': -0.0002
# Token 16 '.              ': +0.0005
# Token 19 'Two            ': +0.0487
# Token 20 'Ġwomen         ': +0.0334
# Token 21 'Ġare           ': +0.0041
# Token 22 'Ġwalking       ': +0.2049
#   Ġpair          : +0.3382
#   Ġwomen         : +0.3342
#   Ġwalking       : +0.2139
#   Two            : +0.0508
#   Ġwomen         : +0.0349
# ['The', 'Ġpremise', 'Ġstates', 'Ġthat', 'Ġone', 'Ġwoman', 'Ġis', 'Ġwalking', 'Ġpast', ',', 'Ġbut', 'Ġit', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġwhether', 'Ġthe', 'Ġother', 'Ġwoman', 'Ġis', 'Ġalso', 'Ġwalking', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġthat', 'Ġboth', 'Ġwomen', 'Ġare', 'Ġwalking', 'Ġis', 'Ġnot', 'Ġnecessarily', 'Ġtrue', ',', 'Ġmaking', 'Ġthe', 'Ġlabel', 'Ġ"', 'neutral', '"', 'Ġappropriate', '.']
#   Ġwomen         : +0.3342
#   Ġwalking       : +0.2139
#   Ġwomen         : +0.0349
# Token  1 'We             ': +0.0348
# Token  2 'Ġsee           ': -0.0498
# Token  3 'Ġthe           ': -0.0343
# Token  4 'Ġbacks         ': -0.0050
# Token  5 'Ġof            ': +0.0126
# Token  6 'Ġa             ': -0.0558
# Token  7 'Ġyoung         ': +0.0257
# Token  8 'ĠAsian         ': +0.0305
# Token  9 'Ġgirl          ': -0.0783
# Token 10 'Ġwith          ': +0.0663
# Token 11 'Ġa             ': +0.0023
# Token 12 'Ġgreen         ': +0.1078
# Token 13 'Ġshirt         ': +0.1816
# Token 14 'Ġand           ': +0.0094
# Token 15 'Ġa             ': -0.0267
# Token 16 'Ġred           ': +0.0413
# Token 17 'Ġhat           ': +0.0105
# Token 18 'Ġholding       ': -0.1250
# Token 19 'Ġhands         ': +0.1942
# Token 20 'Ġwith          ': -0.0505
# Token 21 'Ġa             ': -0.0796
# Token 22 'Ġyoung         ': -0.0172
# Token 23 'ĠAsian         ': +0.0844
# Token 24 'Ġgirl          ': +0.0237
# Token 25 'Ġwith          ': -0.0465
# Token 26 'Ġa             ': -0.0149
# Token 27 'Ġstriped       ': +0.0099
# Token 28 'Ġpink          ': +0.0184
# Token 29 'Ġshirt         ': +0.1833
# Token 30 'Ġand           ': +0.1114
# Token 31 'Ġa             ': +0.1253
# Token 32 'Ġpink          ': +0.1990
# Token 33 'Ġhat           ': +0.4644
# Token 34 'Ġby            ': +0.4612
# Token 35 'Ġthe           ': +0.4465
# Token 36 'Ġpool          ': +0.6442
# Token 37 '.              ': -0.0091
# Token 40 'The            ': -0.1952
# Token 41 'Ġgirls         ': +0.0066
# Token 42 'Ġare           ': -0.1420
# Token 43 'Ġin            ': -0.0297
# Token 44 'Ġdifferent     ': -0.0145
# Token 45 'Ġrooms         ': -0.2360
# Token 46 'Ġon            ': +0.0060
# Token 47 'Ġtop           ': -0.0168
# Token 48 'Ġof            ': +0.0009
# Token 49 'Ġthe           ': -0.0760
# Token 50 'ĠEmpire        ': +0.1465
# Token 51 'ĠState         ': -0.0194
# Token 52 'ĠBuilding      ': +0.1155
# Token 53 '.              ': -0.0688
#   Ġpool          : +0.1250
#   Ġhat           : +0.0901
#   Ġby            : +0.0895
#   Ġthe           : +0.0866
#   Ġrooms         : -0.0458
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġgirls', 'Ġare', 'Ġby', 'Ġa', 'Ġpool', ',', 'Ġwhich', 'Ġis', 'Ġa', 'Ġsingle', ',', 'Ġspecific', 'Ġlocation', '.', 'ĠThe', 'Ġhypothesis', 'Ġclaims', 'Ġthey', 'Ġare', 'Ġin', 'Ġdifferent', 'Ġrooms', 'Ġon', 'Ġtop', 'Ġof', 'Ġthe', 'ĠEmpire', 'ĠState', 'ĠBuilding', ',', 'Ġwhich', 'Ġcontradicts', 'Ġthe', 'Ġpremise', "'s", 'Ġdescription', 'Ġof', 'Ġa', 'Ġshared', 'Ġpool', 'side', 'Ġsetting', '.']
#   Ġpool          : +0.1250
#   Ġby            : +0.0895
#   Ġthe           : +0.0866
# Token  1 'two            ': -0.0000
# Token  2 'Ġman           ': -0.0000
# Token  3 'Ġin            ': -0.0000
# Token  4 'Ġthe           ': +0.0000
# Token  5 'Ġarmy          ': +0.0004
# Token  6 'Ġwith          ': +0.0000
# Token  7 'Ġa             ': -0.0000
# Token  8 'Ġsmall         ': +0.0000
# Token  9 'Ġboy           ': +0.0000
# Token 10 'Ġfrom          ': -0.0000
# Token 11 'Ġthe           ': -0.0000
# Token 12 'Ġarea          ': -0.0000
# Token 13 '.              ': +0.0000
# Token 16 'Two            ': -0.0000
# Token 17 'Ġarmy          ': +0.0000
# Token 18 'Ġguys          ': -0.0000
# Token 19 'Ġtalk          ': -0.0001
# Token 20 'Ġto            ': -0.0000
# Token 21 'Ġa             ': +0.0000
# Token 22 'Ġlittle        ': -0.0000
# Token 23 'Ġboy           ': -0.0000
# Token 24 'Ġabout         ': +0.0030
# Token 25 'Ġarmy          ': -0.0000
# Token 26 'Ġtrucks        ': +0.0009
# Token 27 '.              ': +0.0001
#   Ġabout         : +0.6111
#   Ġtrucks        : +0.1826
#   Ġarmy          : +0.0850
#   Ġtalk          : -0.0168
#   .              : +0.0132
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġtwo', 'Ġmen', 'Ġin', 'Ġthe', 'Ġarmy', 'Ġare', 'Ġwith', 'Ġa', 'Ġsmall', 'Ġboy', ',', 'Ġwithout', 'Ġspecifying', 'Ġany', 'Ġinteraction', '.', 'ĠThe', 'Ġhypothesis', 'Ġintroduces', 'Ġthe', 'Ġspecific', 'Ġaction', 'Ġof', 'Ġtalking', 'Ġabout', 'Ġarmy', 'Ġtrucks', ',', 'Ġwhich', 'Ġis', 'Ġnot', 'Ġsupported', 'Ġby', 'Ġthe', 'Ġpremise', '.', 'ĠSince', 'Ġthe', 'Ġpremise', 'Ġneither', 'Ġconfirms', 'Ġnor', 'Ġcontradicts', 'Ġthis', 'Ġadditional', 'Ġdetail', ',', 'Ġthe', 'Ġrelationship', 'Ġremains', 'Ġneutral', '.']
#   Ġabout         : +0.6111
#   Ġtrucks        : +0.1826
#   Ġarmy          : +0.0850
#   .              : +0.0132
# Token  1 'A              ': -0.0011
# Token  2 'Ġstreet        ': +0.0037
# Token  3 'Ġvendor        ': +0.0023
# Token  4 'Ġsitting       ': +0.1077
# Token  5 'Ġon            ': +0.0004
# Token  6 'Ġa             ': +0.0008
# Token  7 'Ġsidewalk      ': +0.0054
# Token  8 'Ġwith          ': +0.0084
# Token  9 'Ġeggs          ': +0.0036
# Token 10 'Ġand           ': +0.0018
# Token 11 'Ġlive          ': +0.0003
# Token 12 'Ġchickens      ': +0.0019
# Token 13 '.              ': +0.0014
# Token 16 'A              ': +0.0020
# Token 17 'Ġstreet        ': +0.0055
# Token 18 'Ġvendor        ': +0.0077
# Token 19 'Ġis            ': +0.0063
# Token 20 'Ġsitting       ': +0.6511
# Token 21 '.              ': +0.0515
#   Ġsitting       : +0.7545
#   Ġsitting       : +0.1248
#   .              : +0.0597
#   Ġwith          : +0.0097
#   Ġvendor        : +0.0090
# ['The', 'Ġpremise', 'Ġexplicitly', 'Ġstates', 'Ġthat', 'Ġ"', 'a', 'Ġstreet', 'Ġvendor', 'Ġ[', 'is', ']', 'Ġsitting', 'Ġon', 'Ġa', 'Ġsidewalk', ',"', 'Ġwhich', 'Ġdirectly', 'Ġsupports', 'Ġthe', 'Ġhypothesis', 'Ġthat', 'Ġ"', 'a', 'Ġstreet', 'Ġvendor', 'Ġis', 'Ġsitting', '."', 'ĠThe', 'Ġadditional', 'Ġdetails', 'Ġabout', 'Ġeggs', 'Ġand', 'Ġchickens', 'Ġdo', 'Ġnot', 'Ġcontradict', 'Ġor', 'Ġalter', 'Ġthe', 'Ġcore', 'Ġaction', 'Ġdescribed', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġlogically', 'Ġentails', 'Ġthe', 'Ġhypothesis', '.']
#   Ġsitting       : +0.7545
#   Ġsitting       : +0.1248
#   .              : +0.0597
#   Ġvendor        : +0.0090
# Token  1 'A              ': +0.0177
# Token  2 'Ġman           ': +0.4042
# Token  3 'Ġpainted       ': +0.0973
# Token  4 'Ġin            ': +0.0493
# Token  5 'Ġgold          ': +0.2481
# Token  6 'Ġwith          ': +0.0678
# Token  7 'Ġcycle         ': -0.0382
# Token  8 'Ġstands        ': +0.1134
# Token  9 'Ġin            ': +0.0216
# Token 10 'Ġthe           ': +0.0281
# Token 11 'Ġstreet        ': +0.0128
# Token 12 '.              ': +0.0252
# Token 15 'A              ': +0.0039
# Token 16 'Ġman           ': +0.0186
# Token 17 'Ġin            ': +0.0125
# Token 18 'Ġbright        ': +0.0266
# Token 19 'Ġgold          ': +0.0817
# Token 20 'Ġpaint         ': +0.0308
# Token 21 'Ġstands        ': +0.0947
# Token 22 'Ġnear          ': +0.1095
# Token 23 'Ġthe           ': -0.0109
# Token 24 'Ġbuilding      ': +0.1502
# Token 25 'Ġin            ': +0.0034
# Token 26 'Ġthe           ': +0.0158
# Token 27 'Ġstreet        ': +0.0402
# Token 28 '.              ': -0.0068
#   Ġman           : +0.2337
#   Ġgold          : +0.1435
#   Ġbuilding      : +0.0868
#   Ġstands        : +0.0656
#   Ġnear          : +0.0633
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġman', 'Ġis', 'Ġpainted', 'Ġin', 'Ġgold', 'Ġand', 'Ġstands', 'Ġin', 'Ġthe', 'Ġstreet', ',', 'Ġbut', 'Ġit', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġhis', 'Ġproximity', 'Ġto', 'Ġa', 'Ġbuilding', '.', 'ĠWhile', 'Ġthe', 'Ġhypothesis', 'Ġmentions', 'Ġhe', 'Ġstands', 'Ġnear', 'Ġa', 'Ġbuilding', ',', 'Ġthis', 'Ġdetail', 'Ġis', 'Ġnot', 'Ġpresent', 'Ġin', 'Ġthe', 'Ġpremise', ',', 'Ġso', 'Ġthe', 'Ġrelationship', 'Ġcannot', 'Ġbe', 'Ġconfirmed', 'Ġor', 'Ġcontradicted', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġinference', 'Ġis', 'Ġneutral', '.']
#   Ġman           : +0.2337
#   Ġgold          : +0.1435
#   Ġbuilding      : +0.0868
#   Ġstands        : +0.0656
#   Ġnear          : +0.0633
# Token  1 'With           ': +0.0023
# Token  2 'Ġa             ': +0.0000
# Token  3 'Ġbeautiful     ': -0.0002
# Token  4 'Ġblue          ': +0.0028
# Token  5 'Ġsky           ': +0.0158
# Token  6 'Ġand           ': -0.0020
# Token  7 'Ġgreen         ': -0.0046
# Token  8 'Ġmountains     ': +0.4004
# Token  9 'Ġin            ': -0.0044
# Token 10 'Ġthe           ': -0.0016
# Token 11 'Ġbackground    ': -0.0021
# Token 12 ',              ': +0.0000
# Token 13 'Ġa             ': -0.0012
# Token 14 'Ġman           ': -0.0016
# Token 15 'Ġin            ': -0.0002
# Token 16 'Ġblue          ': +0.0047
# Token 17 'Ġshorts        ': +0.0006
# Token 18 'Ġand           ': +0.0007
# Token 19 'Ġa             ': +0.0000
# Token 20 'Ġblue          ': -0.0004
# Token 21 'Ġshirt         ': +0.0003
# Token 22 'Ġw             ': +0.0004
# Token 23 'ades           ': +0.0011
# Token 24 'Ġthrough       ': -0.0011
# Token 25 'Ġthe           ': +0.0034
# Token 26 'Ġshallow       ': +0.0034
# Token 27 ',              ': +0.0009
# Token 28 'Ġclear         ': +0.0036
# Token 29 'Ġwaters        ': +0.0059
# Token 30 'Ġcarry         ': +0.0032
# Token 31 'Ġsomething     ': +0.0106
# Token 32 'Ġwhite         ': +0.0022
# Token 33 '.              ': -0.0011
# Token 36 'Man            ': +0.0007
# Token 37 'Ġin            ': -0.0003
# Token 38 'Ġblue          ': +0.0075
# Token 39 'Ġw             ': -0.0007
# Token 40 'ades           ': -0.0010
# Token 41 'Ġthrough       ': +0.0047
# Token 42 'Ġwater         ': +0.0378
# Token 43 'Ġin            ': +0.0004
# Token 44 'Ġfront         ': -0.0022
# Token 45 'Ġof            ': +0.0014
# Token 46 'Ġa             ': +0.0137
# Token 47 'Ġbeautiful     ': +0.0227
# Token 48 'Ġmountain      ': +0.0083
# Token 49 'Ġscene         ': +0.0616
# Token 50 '.              ': +0.0007
#   Ġmountains     : +0.6196
#   Ġscene         : +0.0954
#   Ġwater         : +0.0584
#   Ġbeautiful     : +0.0351
#   Ġsky           : +0.0245
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġman', 'Ġis', 'Ġin', 'Ġblue', 'Ġshorts', 'Ġand', 'Ġa', 'Ġblue', 'Ġshirt', ',', 'Ġwhich', 'Ġmatches', 'Ġ"', 'man', 'Ġin', 'Ġblue', ',"', 'Ġand', 'Ġdescribes', 'Ġhim', 'Ġw', 'ading', 'Ġthrough', 'Ġshallow', ',', 'Ġclear', 'Ġwaters', 'Ġwith', 'Ġgreen', 'Ġmountains', 'Ġand', 'Ġa', 'Ġblue', 'Ġsky', 'Ġin', 'Ġthe', 'Ġbackground', ',', 'Ġdirectly', 'Ġsupporting', 'Ġthe', 'Ġmountain', 'Ġscene', 'Ġdescription', '.', 'ĠAll', 'Ġkey', 'Ġelements', 'Ġin', 'Ġthe', 'Ġhypothesis', 'Ġare', 'Ġexplicitly', 'Ġmentioned', 'Ġor', 'Ġlogically', 'Ġinferred', 'Ġfrom', 'Ġthe', 'Ġpremise', '.']
#   Ġmountains     : +0.6196
#   Ġscene         : +0.0954
#   Ġsky           : +0.0245
# Token  1 'A              ': -0.0901
# Token  2 'Ġlarge         ': -0.1238
# Token  3 'Ġcrowd         ': -0.1463
# Token  4 'Ġof            ': +0.0466
# Token  5 'Ġpeople        ': -0.1728
# Token  6 'Ġare           ': +0.0003
# Token  7 'Ġwalking       ': -0.2192
# Token  8 '.              ': -0.0858
# Token 11 'A              ': +0.0673
# Token 12 'Ġlarge         ': +0.0856
# Token 13 'Ġcrowd         ': -0.0687
# Token 14 'Ġis            ': -0.0483
# Token 15 'Ġtouring       ': +0.0483
# Token 16 'Ġa             ': -0.0238
# Token 17 'Ġmuseum        ': -0.0107
# Token 18 '.              ': +0.1860
#   Ġwalking       : -0.1540
#   .              : +0.1306
#   Ġpeople        : -0.1214
#   Ġcrowd         : -0.1027
#   Ġlarge         : -0.0870
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġa', 'Ġlarge', 'Ġcrowd', 'Ġis', 'Ġwalking', ',', 'Ġwhich', 'Ġcould', 'Ġoccur', 'Ġin', 'Ġmany', 'Ġdifferent', 'Ġcontexts', '.', 'ĠThe', 'Ġhypothesis', 'Ġspecifies', 'Ġthat', 'Ġthe', 'Ġcrowd', 'Ġis', 'Ġtouring', 'Ġa', 'Ġmuseum', ',', 'Ġwhich', 'Ġis', 'Ġone', 'Ġpossible', 'Ġscenario', 'Ġbut', 'Ġnot', 'Ġnecessarily', 'Ġtrue', 'Ġbased', 'Ġon', 'Ġthe', 'Ġpremise', 'Ġalone', '.', 'ĠSince', 'Ġthe', 'Ġpremise', 'Ġdoes', 'Ġnot', 'Ġprovide', 'Ġinformation', 'Ġabout', 'Ġthe', 'Ġlocation', 'Ġor', 'Ġpurpose', 'Ġof', 'Ġthe', 'Ġwalking', ',', 'Ġthe', 'Ġrelationship', 'Ġremains', 'Ġneutral', '.']
#   .              : +0.1306
# Token  1 'Two            ': +0.5245
# Token  2 'Ġelderly       ': -0.0044
# Token  3 'Ġpeople        ': +0.1188
# Token  4 'Ġsit           ': +0.0321
# Token  5 'Ġin            ': -0.0477
# Token  6 'Ġhandic        ': +0.0198
# Token  7 'apped          ': +0.0037
# Token  8 'Ġchairs        ': +0.0062
# Token  9 'Ġon            ': -0.1233
# Token 10 'Ġa             ': +0.0103
# Token 11 'Ġtrain         ': -0.2256
# Token 12 '.              ': -0.0292
# Token 15 'Two            ': -0.1311
# Token 16 'Ġpeople        ': +0.0035
# Token 17 'Ġare           ': +0.0253
# Token 18 'Ġon            ': -0.0608
# Token 19 'Ġa             ': +0.0371
# Token 20 'Ġlong          ': +0.6616
# Token 21 'Ġtrain         ': +0.4085
# Token 22 'Ġride          ': -0.1795
# Token 23 '.              ': -0.0731
#   Ġlong          : +0.2427
#   Two            : +0.1924
#   Ġtrain         : +0.1498
#   Ġtrain         : -0.0827
#   Ġride          : -0.0658
# ['The', 'Ġpremise', 'Ġstates', 'Ġthey', 'Ġare', 'Ġsitting', 'Ġon', 'Ġa', 'Ġtrain', 'Ġbut', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġthe', 'Ġduration', 'Ġof', 'Ġthe', 'Ġjourney', '.', 'ĠA', 'Ġtrain', 'Ġride', 'Ġcould', 'Ġbe', 'Ġshort', 'Ġor', 'Ġlong', ',', 'Ġso', 'Ġwe', 'Ġcannot', 'Ġdefinitively', 'Ġconclude', 'Ġthe', 'Ġhypothesis', 'Ġis', 'Ġtrue', 'Ġor', 'Ġfalse', '.']
#   Ġlong          : +0.2427
#   Ġtrain         : +0.1498
# Token  1 'A              ': +0.0007
# Token  2 'Ġwoman         ': -0.0000
# Token  3 'Ġcuts          ': -0.0001
# Token  4 'Ġa             ': -0.0001
# Token  5 'Ġcake          ': +0.0006
# Token  6 'Ġwhile         ': +0.0000
# Token  7 'Ġthe           ': -0.0000
# Token  8 'Ġwoman         ': +0.0000
# Token  9 'Ġnext          ': +0.0000
# Token 10 'Ġto            ': -0.0000
# Token 11 'Ġher           ': +0.0000
# Token 12 'Ġholds         ': -0.0000
# Token 13 'Ġout           ': -0.0001
# Token 14 'Ġa             ': -0.0000
# Token 15 'Ġplate         ': -0.0001
# Token 16 '.              ': +0.0028
# Token 19 'the            ': +0.0338
# Token 20 'Ġwoman         ': -0.0000
# Token 21 'Ġis            ': +0.0027
# Token 22 'Ġat            ': +0.0101
# Token 23 'Ġa             ': +0.0003
# Token 24 'Ġparty         ': +0.3706
#   Ġparty         : +0.8779
#   the            : +0.0801
#   Ġat            : +0.0240
#   .              : +0.0066
#   Ġis            : +0.0063
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġwoman', 'Ġcutting', 'Ġa', 'Ġcake', 'Ġwhile', 'Ġanother', 'Ġholds', 'Ġa', 'Ġplate', ',', 'Ġwhich', 'Ġcould', 'Ġoccur', 'Ġin', 'Ġvarious', 'Ġsettings', 'Ġsuch', 'Ġas', 'Ġa', 'Ġbirthday', 'Ġcelebration', ',', 'Ġfamily', 'Ġgathering', ',', 'Ġor', 'Ġcasual', 'Ġevent', '.', 'ĠWhile', 'Ġparties', 'Ġoften', 'Ġinvolve', 'Ġcake', '-', 'cutting', ',', 'Ġthe', 'Ġpremise', 'Ġdoes', 'Ġnot', 'Ġprovide', 'Ġspecific', 'Ġdetails', 'Ġlike', 'Ġdecorations', ',', 'Ġguests', ',', 'Ġor', 'Ġexplicit', 'Ġmentions', 'Ġof', 'Ġa', 'Ġparty', 'Ġcontext', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġcannot', 'Ġbe', 'Ġconfirmed', 'Ġor', 'Ġdenied', 'Ġbased', 'Ġsolely', 'Ġon', 'Ġthe', 'Ġgiven', 'Ġinformation', '.']
#   Ġparty         : +0.8779
#   .              : +0.0066
# Token  1 'A              ': +0.0332
# Token  2 'Ġperson        ': -0.0132
# Token  3 'Ġwith          ': +0.5812
# Token  4 'Ġa             ': +0.0190
# Token  5 'Ġbag           ': +0.0396
# Token  6 'Ġwalking       ': +0.2211
# Token  7 'Ġin            ': +0.0222
# Token  8 'Ġa             ': +0.0035
# Token  9 'Ġbig           ': +0.0368
# Token 10 'Ġcity          ': -0.0774
# Token 11 '.              ': +0.0213
# Token 14 'The            ': -0.0268
# Token 15 'Ġman           ': -0.0329
# Token 16 'Ġdropped       ': +0.7490
# Token 17 'Ġhis           ': +0.0128
# Token 18 'Ġbag           ': -0.0853
# Token 19 'Ġon            ': +0.0833
# Token 20 'Ġthe           ': +0.0079
# Token 21 'Ġstreet        ': +0.0222
# Token 22 '.              ': +0.0241
#   Ġdropped       : +0.3545
#   Ġwith          : +0.2751
#   Ġwalking       : +0.1047
#   Ġbag           : -0.0404
#   Ġon            : +0.0394
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġa', 'Ġperson', 'Ġis', 'Ġwalking', 'Ġwith', 'Ġa', 'Ġbag', 'Ġin', 'Ġa', 'Ġcity', ',', 'Ġwhich', 'Ġdoes', 'Ġnot', 'Ġimply', 'Ġany', 'Ġaction', 'Ġinvolving', 'Ġdropping', 'Ġthe', 'Ġbag', '.', 'ĠThe', 'Ġhypothesis', 'Ġintroduces', 'Ġthe', 'Ġspecific', 'Ġevent', 'Ġof', 'Ġthe', 'Ġbag', 'Ġbeing', 'Ġdropped', ',', 'Ġwhich', 'Ġdirectly', 'Ġcontradicts', 'Ġthe', 'Ġneutral', 'Ġdescription', 'Ġof', 'Ġsimply', 'Ġwalking', 'Ġwith', 'Ġthe', 'Ġbag', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġcannot', 'Ġsupport', 'Ġthe', 'Ġhypothesis', '.']
#   Ġdropped       : +0.3545
#   Ġwith          : +0.2751
#   Ġwalking       : +0.1047
# Token  1 '14             ': +0.0404
# Token  2 'Ġmen           ': +0.0308
# Token  3 'Ġstanding      ': +0.0645
# Token  4 'Ġon            ': -0.0152
# Token  5 'Ġa             ': -0.0117
# Token  6 'Ġstair         ': -0.0101
# Token  7 'way            ': -0.0095
# Token  8 'Ġoutside       ': +0.0338
# Token  9 'Ġalmost        ': -0.0015
# Token 10 'Ġall           ': -0.0036
# Token 11 'Ġwearing       ': -0.0002
# Token 12 'Ġthe           ': -0.0028
# Token 13 'Ġsame          ': -0.0149
# Token 14 'Ġshirt         ': -0.0167
# Token 15 '.              ': +0.0027
# Token 18 '14             ': +0.0135
# Token 19 'Ġmen           ': +0.0121
# Token 20 'Ġposing        ': -0.0045
# Token 21 'Ġfor           ': +0.0531
# Token 22 'Ġa             ': +0.0394
# Token 23 'Ġpicture       ': +0.0866
# Token 24 '.              ': +0.0093
#   Ġpicture       : +0.1816
#   Ġstanding      : +0.1352
#   Ġfor           : +0.1114
#   14             : +0.0847
#   Ġa             : +0.0827
# ['The', 'Ġpremise', 'Ġdoes', 'Ġnot', 'Ġmention', 'Ġanything', 'Ġabout', 'Ġposing', 'Ġor', 'Ġtaking', 'Ġa', 'Ġpicture', ',', 'Ġonly', 'Ġthat', 'Ġthe', 'Ġmen', 'Ġare', 'Ġstanding', 'Ġon', 'Ġa', 'Ġstair', 'way', '.', 'ĠWhile', 'Ġstanding', 'Ġcould', 'Ġbe', 'Ġpart', 'Ġof', 'Ġposing', ',', 'Ġit', 'Ġis', 'Ġnot', 'Ġnecessarily', 'Ġthe', 'Ġcase', ',', 'Ġso', 'Ġthe', 'Ġhypothesis', 'Ġcannot', 'Ġbe', 'Ġconfirmed', 'Ġor', 'Ġcontradicted', '.']
#   Ġpicture       : +0.1816
#   Ġstanding      : +0.1352
#   Ġa             : +0.0827
# Token  1 'Two            ': +0.0008
# Token  2 'Ġchildren      ': +0.0004
# Token  3 'Ġwalking       ': +0.0039
# Token  4 'Ġdown          ': +0.0052
# Token  5 'Ġa             ': +0.0015
# Token  6 'Ġpath          ': +0.0076
# Token  7 'Ġin            ': +0.0071
# Token  8 'Ġthe           ': +0.0007
# Token  9 'Ġwoods         ': +0.5778
# Token 10 '.              ': +0.0012
# Token 13 'There          ': -0.0010
# Token 14 'Ġare           ': +0.0001
# Token 15 'Ġkids          ': +0.0054
# Token 16 'Ġat            ': +0.0021
# Token 17 'Ġa             ': +0.0015
# Token 18 'Ġbeach         ': +0.9628
# Token 19 '.              ': +0.0002
#   Ġbeach         : +0.6097
#   Ġwoods         : +0.3659
#   Ġpath          : +0.0048
#   Ġin            : +0.0045
#   Ġkids          : +0.0034
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġchildren', 'Ġwalking', 'Ġin', 'Ġthe', 'Ġwoods', ',', 'Ġwhich', 'Ġis', 'Ġa', 'Ġforest', 'Ġenvironment', '.', 'ĠA', 'Ġbeach', 'Ġis', 'Ġa', 'Ġcoastal', 'Ġenvironment', 'Ġfundamentally', 'Ġdifferent', 'Ġfrom', 'Ġwoods', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġdirectly', 'Ġcontradicts', 'Ġthe', 'Ġhypothesis', 'Ġabout', 'Ġchildren', 'Ġbeing', 'Ġat', 'Ġa', 'Ġbeach', '.']
#   Ġbeach         : +0.6097
#   Ġwoods         : +0.3659
#   Ġin            : +0.0045
# Token  1 'Young          ': -0.0968
# Token  2 'Ġpeople        ': -0.0296
# Token  3 'Ġare           ': +0.0290
# Token  4 'Ġplaying       ': -0.1260
# Token  5 'Ġin            ': -0.0525
# Token  6 'Ġthe           ': -0.2344
# Token  7 'Ġsnow          ': +0.6134
# Token  8 'Ġwhile         ': +0.0661
# Token  9 'Ġan            ': +0.0054
# Token 10 'Ġolder         ': +0.0708
# Token 11 'Ġperson        ': -0.0183
# Token 12 'Ġseems         ': +0.0478
# Token 13 'Ġto            ': +0.0101
# Token 14 'Ġbe            ': -0.0110
# Token 15 'Ġtaking        ': -0.0133
# Token 16 'Ġpictures      ': -0.0179
# Token 17 '.              ': +0.0506
# Token 20 'Young          ': -0.0300
# Token 21 'Ġpeople        ': -0.0694
# Token 22 'Ġplay          ': -0.1397
# Token 23 'Ġin            ': -0.0042
# Token 24 'Ġthe           ': +0.1803
# Token 25 'Ġfresh         ': -0.1126
# Token 26 'Ġsnow          ': -0.1884
# Token 27 '.              ': +0.2248
#   Ġsnow          : +0.2511
#   Ġthe           : -0.0960
#   .              : +0.0920
#   Ġsnow          : -0.0771
#   Ġthe           : +0.0738
# ['The', 'Ġpremise', 'Ġstates', 'Ġthat', 'Ġyoung', 'Ġpeople', 'Ġare', 'Ġplaying', 'Ġin', 'Ġsnow', ',', 'Ġbut', 'Ġit', 'Ġdoes', 'Ġnot', 'Ġspecify', 'Ġwhether', 'Ġthe', 'Ġsnow', 'Ġis', 'Ġfresh', '.', 'ĠThe', 'Ġhypothesis', 'Ġadds', 'Ġthe', 'Ġdetail', 'Ġthat', 'Ġthe', 'Ġsnow', 'Ġis', 'Ġfresh', ',', 'Ġwhich', 'Ġis', 'Ġnot', 'Ġsupported', 'Ġby', 'Ġthe', 'Ġpremise', '.', 'ĠSince', 'Ġthe', 'Ġpremise', 'Ġneither', 'Ġconfirms', 'Ġnor', 'Ġdenies', 'Ġthis', 'Ġadditional', 'Ġdetail', ',', 'Ġthe', 'Ġrelationship', 'Ġis', 'Ġneutral', '.']
#   Ġsnow          : +0.2511
#   .              : +0.0920
#   Ġthe           : +0.0738
# Token  1 'Person         ': +0.0014
# Token  2 'Ġin            ': +0.0152
# Token  3 'Ġblue          ': +0.0039
# Token  4 'Ġjacket        ': +0.0037
# Token  5 'Ġon            ': +0.0080
# Token  6 'Ġa             ': +0.0042
# Token  7 'Ġbike          ': +0.1795
# Token  8 'Ġon            ': +0.0170
# Token  9 'Ġa             ': +0.0006
# Token 10 'Ġdirt          ': -0.0016
# Token 11 'Ġcourse        ': -0.0068
# Token 12 'Ġwith          ': +0.0421
# Token 13 'Ġpeople        ': +0.0314
# Token 14 'Ġlooking       ': +0.0235
# Token 15 'Ġfrom          ': +0.0142
# Token 16 'Ġbehind        ': +0.0224
# Token 17 'Ġa             ': +0.0032
# Token 18 'Ġred           ': +0.0016
# Token 19 'Ġand           ': +0.0016
# Token 20 'Ġwhite         ': +0.0022
# Token 21 'Ġbarrier       ': +0.0016
# Token 22 '.              ': -0.0002
# ...
# Token  3 'Ġplayer        ': -0.0053
# Token  4 'Ġprepares      ': -0.0015
# Token  5 'Ġfor           ': -0.0019
# Token  6 'Ġa             ': -0.0023
# Token  7 'Ġcorner        ': -0.0061
# Token  8 'Ġkick          ': -0.0030
# Token  9 '.              ': -0.0011
# Token 12 'The            ': +0.0032
# Token 13 'Ġsoccer        ': -0.0166
# Token 14 'Ġplayer        ': -0.0001
# Token 15 'Ġis            ': +0.0355
# Token 16 'Ġplaying       ': +0.2146
# Token 17 'Ġsoccer        ': +0.8877
# Token 18 '.              ': +0.0459
#   Ġsoccer        : +0.5620
#   Ġsoccer        : +0.2195
#   Ġplaying       : +0.1359
#   .              : +0.0291
#   Ġis            : +0.0225
# ['A', 'Ġcorner', 'Ġkick', 'Ġis', 'Ġa', 'Ġstandard', 'Ġpart', 'Ġof', 'Ġsoccer', 'Ġgameplay', '.', 'ĠWhen', 'Ġa', 'Ġplayer', 'Ġprepares', 'Ġfor', 'Ġa', 'Ġcorner', 'Ġkick', ',', 'Ġthey', 'Ġare', 'Ġactively', 'Ġparticipating', 'Ġin', 'Ġa', 'Ġsoccer', 'Ġmatch', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġpremise', 'Ġdirectly', 'Ġsupports', 'Ġthe', 'Ġconclusion', 'Ġthat', 'Ġthe', 'Ġplayer', 'Ġis', 'Ġplaying', 'Ġsoccer', '.']
#   Ġsoccer        : +0.5620
#   Ġsoccer        : +0.2195
#   Ġplaying       : +0.1359
#   .              : +0.0291
#   Ġis            : +0.0225
# Token  1 'A              ': -0.0000
# Token  2 'Ġheav          ': +0.0003
# Token  3 'ys             ': +0.0000
# Token  4 'et             ': +0.0004
# Token  5 'Ġman           ': -0.0000
# Token  6 'Ġrunning       ': +0.0001
# Token  7 'Ġa             ': +0.0004
# Token  8 'ĠPro           ': +0.0001
# Token  9 '-              ': +0.0001
# Token 10 'S              ': +0.0002
# Token 11 'aw             ': +0.0002
# Token 12 'Ġconcrete      ': +0.0002
# Token 13 'Ġsaw           ': +0.0002
# Token 14 'Ġwith          ': +0.0001
# Token 15 'Ġa             ': -0.0002
# Token 16 'Ġpiece         ': +0.0002
# Token 17 'Ġof            ': -0.0000
# Token 18 'Ġwhite         ': +0.0021
# Token 19 'Ġconstruction  ': -0.0002
# Token 20 'Ġequipment     ': -0.0001
# Token 21 'Ġin            ': +0.0001
# Token 22 'Ġthe           ': -0.0000
# Token 23 'Ġbackground    ': +0.0434
# Token 24 '.              ': -0.0002
# Token 27 'There          ': +0.0002
# Token 28 'Ġis            ': +0.0000
# Token 29 'Ġa             ': +0.0001
# Token 30 'Ġpiece         ': -0.0000
# Token 31 'Ġof            ': -0.0000
# Token 32 'Ġwhite         ': +0.0056
# Token 33 'Ġconstruction  ': +0.0004
# Token 34 'Ġequipment     ': +0.0001
# Token 35 'Ġbehind        ': +0.0822
# Token 36 'Ġthe           ': +0.0001
# Token 37 'Ġheav          ': +0.0007
# Token 38 'ys             ': +0.0003
# Token 39 'et             ': +0.0001
# Token 40 'Ġman           ': +0.0002
# Token 41 '.              ': -0.0001
#   Ġbehind        : +0.5921
#   Ġbackground    : +0.3127
#   Ġwhite         : +0.0401
#   Ġwhite         : +0.0152
#   Ġheav          : +0.0050
# ['The', 'Ġpremise', 'Ġexplicitly', 'Ġstates', 'Ġthere', 'Ġis', 'Ġ"', 'a', 'Ġpiece', 'Ġof', 'Ġwhite', 'Ġconstruction', 'Ġequipment', 'Ġin', 'Ġthe', 'Ġbackground', '"', 'Ġwhile', 'Ġdescribing', 'Ġthe', 'Ġman', 'Ġusing', 'Ġthe', 'Ġconcrete', 'Ġsaw', '.', 'ĠSince', 'Ġthe', 'Ġman', 'Ġis', 'Ġthe', 'Ġcentral', 'Ġsubject', 'Ġof', 'Ġthe', 'Ġscene', ',', 'Ġanything', 'Ġdescribed', 'Ġas', 'Ġbeing', 'Ġin', 'Ġthe', 'Ġbackground', 'Ġwould', 'Ġlogically', 'Ġbe', 'Ġpositioned', 'Ġbehind', 'Ġhim', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġdirectly', 'Ġfollows', 'Ġfrom', 'Ġthe', 'Ġinformation', 'Ġprovided', 'Ġin', 'Ġthe', 'Ġpremise', '.']
#   Ġbehind        : +0.5921
#   Ġbackground    : +0.3127
#   Ġwhite         : +0.0401
#   Ġwhite         : +0.0152
# Token  1 'A              ': +0.0009
# Token  2 'Ġdog           ': +0.0029
# Token  3 'Ġwalking       ': +0.0020
# Token  4 'Ġthrough       ': +0.0003
# Token  5 'Ġa             ': +0.0000
# Token  6 'Ġsmall         ': +0.0001
# Token  7 'Ġstream        ': +0.0028
# Token  8 'Ġwith          ': +0.0002
# Token  9 'Ġa             ': +0.0001
# Token 10 'Ġrag           ': +0.0008
# Token 11 'Ġin            ': +0.0000
# Token 12 'Ġhis           ': +0.0001
# Token 13 'Ġmouth         ': +0.0001
# Token 14 '.              ': +0.0005
# Token 17 'the            ': +0.0024
# Token 18 'Ġdog           ': +0.0006
# Token 19 'Ġsat           ': +0.0016
# Token 20 'Ġon            ': +0.0005
# Token 21 'Ġthe           ': +0.0004
# Token 22 'Ġwindow        ': +0.0010
# Token 23 'Ġledge         ': +0.0002
# Token 24 'Ġwatching      ': +0.0011
# Token 25 'Ġthe           ': +0.0000
# Token 26 'Ġstorm         ': -0.0003
#   Ġdog           : +0.1513
#   Ġstream        : +0.1485
#   the            : +0.1253
#   Ġwalking       : +0.1032
#   Ġsat           : +0.0853
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġdog', 'Ġactively', 'Ġwalking', 'Ġthrough', 'Ġa', 'Ġstream', 'Ġwith', 'Ġan', 'Ġobject', 'Ġin', 'Ġits', 'Ġmouth', ',', 'Ġwhich', 'Ġrequires', 'Ġmovement', 'Ġand', 'Ġengagement', '.', 'ĠThe', 'Ġhypothesis', 'Ġdescribes', 'Ġa', 'Ġdog', 'Ġsitting', 'Ġstationary', 'Ġon', 'Ġa', 'Ġwindow', 'Ġledge', ',', 'Ġwhich', 'Ġis', 'Ġa', 'Ġcompletely', 'Ġdifferent', 'Ġphysical', 'Ġposition', 'Ġand', 'Ġactivity', '.', 'ĠThese', 'Ġtwo', 'Ġscenarios', 'Ġcannot', 'Ġbe', 'Ġsimultaneously', 'Ġtrue', 'Ġfor', 'Ġthe', 'Ġsame', 'Ġdog', 'Ġat', 'Ġthe', 'Ġsame', 'Ġtime', '.']
#   Ġdog           : +0.1513
#   Ġstream        : +0.1485
#   Ġwalking       : +0.1032
# Token  1 'A              ': +0.0001
# Token  2 'Ġman           ': +0.0000
# Token  3 'Ġwearing       ': +0.0001
# Token  4 'Ġa             ': -0.0001
# Token  5 'Ġblack         ': +0.6047
# Token  6 'Ġbackwards     ': +0.0138
# Token  7 'Ġhat           ': +0.0536
# Token  8 'Ġand           ': -0.0001
# Token  9 'Ġa             ': -0.0000
# Token 10 'Ġgray          ': +0.0018
# Token 11 'Ġshirt         ': +0.0002
# Token 12 'Ġwith          ': +0.0001
# Token 13 'Ġa             ': +0.0000
# Token 14 'Ġlarge         ': +0.0002
# Token 15 'Ġear           ': +0.0001
# Token 16 'Ġgauge         ': +0.0001
# Token 17 'Ġwalks         ': +0.0001
# Token 18 'Ġthrough       ': +0.0001
# Token 19 'Ġa             ': +0.0000
# Token 20 'Ġfish          ': +0.0002
# Token 21 'Ġmarket        ': +0.0002
# Token 22 '.              ': -0.0001
# Token 25 'A              ': -0.0003
# Token 26 'Ġguy           ': +0.0006
# Token 27 'Ġis            ': +0.0001
# Token 28 'Ġwearing       ': +0.0005
# Token 29 'Ġa             ': +0.0004
# Token 30 'Ġred           ': +0.9008
# Token 31 'Ġhat           ': +0.0041
# Token 32 '.              ': -0.0000
#   Ġred           : +0.5693
#   Ġblack         : +0.3821
#   Ġhat           : +0.0339
#   Ġbackwards     : +0.0087
#   Ġhat           : +0.0026
# ['The', 'Ġpremise', 'Ġstates', 'Ġthe', 'Ġman', 'Ġis', 'Ġwearing', 'Ġa', 'Ġblack', 'Ġhat', ',', 'Ġwhile', 'Ġthe', 'Ġhypothesis', 'Ġdescribes', 'Ġa', 'Ġred', 'Ġhat', '.', 'ĠSince', 'Ġthese', 'Ġare', 'Ġdifferent', 'Ġcolors', 'Ġthat', 'Ġcannot', 'Ġboth', 'Ġbe', 'Ġtrue', 'Ġfor', 'Ġthe', 'Ġsame', 'Ġhat', ',', 'Ġthe', 'Ġstatements', 'Ġdirectly', 'Ġcontradict', 'Ġeach', 'Ġother', '.']
#   Ġred           : +0.5693
#   Ġblack         : +0.3821
#   Ġhat           : +0.0339
#   Ġhat           : +0.0026
# Token  1 'Two            ': +0.0005
# Token  2 'Ġgirls         ': +0.0013
# Token  3 'Ġcleaning      ': +0.0106
# Token  4 'Ġa             ': +0.0021
# Token  5 'Ġfloor         ': +0.0255
# Token  6 '.              ': +0.0041
# Token  9 'Two            ': -0.0000
# Token 10 'Ġgirls         ': -0.0000
# Token 11 'Ġcleaning      ': +0.1241
# Token 12 'Ġafter         ': +0.0013
# Token 13 'Ġtheir         ': +0.0131
# Token 14 'Ġwork          ': +0.0003
# Token 15 'Ġshift         ': +0.0195
# Token 16 '.              ': +0.0001
#   Ġcleaning      : +0.6124
#   Ġfloor         : +0.1260
#   Ġshift         : +0.0964
#   Ġtheir         : +0.0645
#   Ġcleaning      : +0.0522
# ['The', 'Ġpremise', 'Ġonly', 'Ġstates', 'Ġthat', 'Ġthe', 'Ġgirls', 'Ġare', 'Ġcleaning', 'Ġa', 'Ġfloor', ',', 'Ġwithout', 'Ġspecifying', 'Ġthe', 'Ġreason', 'Ġor', 'Ġtiming', '.', 'ĠThe', 'Ġhypothesis', 'Ġintroduces', 'Ġthe', 'Ġidea', 'Ġthat', 'Ġthis', 'Ġcleaning', 'Ġoccurs', 'Ġafter', 'Ġa', 'Ġwork', 'Ġshift', ',', 'Ġwhich', 'Ġis', 'Ġnot', 'Ġsupported', 'Ġby', 'Ġthe', 'Ġpremise', '.', 'ĠSince', 'Ġthe', 'Ġpremise', 'Ġdoes', 'Ġnot', 'Ġconfirm', 'Ġor', 'Ġcontradict', 'Ġthis', 'Ġadditional', 'Ġdetail', ',', 'Ġthe', 'Ġrelationship', 'Ġis', 'Ġneutral', '.']
#   Ġcleaning      : +0.6124
#   Ġfloor         : +0.1260
#   Ġshift         : +0.0964
#   Ġcleaning      : +0.0522
# Token  1 'A              ': +0.1082
# Token  2 'Ġgroup         ': -0.0036
# Token  3 'Ġof            ': +0.0188
# Token  4 'Ġchildren      ': +0.0635
# Token  5 'Ġplay          ': +0.0604
# Token  6 'Ġjump          ': -0.0225
# Token  7 'Ġrope          ': -0.0066
# Token  8 'Ġin            ': -0.0041
# Token  9 'Ġthe           ': -0.0495
# Token 10 'Ġstreets       ': +0.1640
# Token 11 'Ġwhile         ': -0.0147
# Token 12 'Ġothers        ': +0.0785
# Token 13 'Ġwatch         ': +0.0024
# Token 14 'Ġin            ': +0.0407
# Token 15 'Ġthe           ': +0.0210
# Token 16 'Ġbackground    ': +0.3370
# Token 17 '.              ': -0.0959
# Token 20 'A              ': +0.1467
# Token 21 'Ġbrilliant     ': +0.1195
# Token 22 'Ġred           ': +0.2014
# Token 23 'Ġsun           ': +0.1384
# Token 24 'Ġsets          ': +0.0634
# Token 25 'Ġover          ': +0.0505
# Token 26 'Ġa             ': -0.0279
# Token 27 'Ġdeserted      ': +0.1865
# Token 28 'Ġbeach         ': -0.0969
#   Ġbackground    : +0.1588
#   Ġred           : +0.0949
#   Ġdeserted      : +0.0879
#   Ġstreets       : +0.0773
#   A              : +0.0691
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġchildren', 'Ġplaying', 'Ġjump', 'Ġrope', 'Ġin', 'Ġstreets', 'Ġwith', 'Ġonlook', 'ers', ',', 'Ġindicating', 'Ġan', 'Ġactive', 'Ġurban', 'Ġsetting', 'Ġwith', 'Ġpeople', 'Ġpresent', '.', 'ĠThe', 'Ġhypothesis', 'Ġdepicts', 'Ġa', 'Ġdeserted', 'Ġbeach', 'Ġat', 'Ġsunset', ',', 'Ġdescribing', 'Ġan', 'Ġempty', 'Ġnatural', 'Ġenvironment', '.', 'ĠThese', 'Ġtwo', 'Ġscenarios', 'Ġcannot', 'Ġsimultaneously', 'Ġbe', 'Ġtrue', 'Ġas', 'Ġthey', 'Ġdescribe', 'Ġcompletely', 'Ġdifferent', 'Ġlocations', 'Ġwith', 'Ġcontradictory', 'Ġcharacteristics', '.']
#   Ġdeserted      : +0.0879
#   Ġstreets       : +0.0773
# Token  1 'Four           ': +0.6032
# Token  2 'Ġmen           ': +0.1711
# Token  3 'Ġare           ': -0.0511
# Token  4 'Ġroll          ': -0.0851
# Token  5 'ers            ': -0.0123
# Token  6 'k              ': -0.0253
# Token  7 'ating          ': -0.0096
# Token  8 'Ġin            ': -0.0390
# Token  9 'Ġa             ': +0.0177
# Token 10 'Ġline          ': -0.0034
# Token 11 ',              ': -0.0516
# Token 12 'Ġwith          ': -0.0440
# Token 13 'Ġthe           ': -0.0125
# Token 14 'Ġlast          ': -0.0222
# Token 15 'Ġthree         ': -0.1006
# Token 16 'Ġholding       ': -0.0627
# Token 17 'Ġonto          ': +0.0033
# Token 18 'Ġthe           ': +0.0067
# Token 19 'Ġhips          ': +0.0060
# Token 20 'Ġof            ': -0.0331
# Token 21 'Ġthe           ': -0.0048
# Token 22 'Ġman           ': -0.0644
# Token 23 'Ġahead         ': -0.0157
# Token 24 'Ġof            ': +0.0042
# Token 25 'Ġthem          ': -0.0308
# Token 26 '.              ': +0.0238
# Token 29 'T              ': +0.5979
# Token 30 'all            ': +0.6804
# Token 31 'Ġmen           ': +0.3953
# Token 32 'Ġskating       ': -0.0499
# Token 33 '.              ': -0.1024
#   all            : +0.2043
#   Four           : +0.1811
#   T              : +0.1796
#   Ġmen           : +0.1187
#   Ġmen           : +0.0514
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġthe', 'Ġnumber', 'Ġof', 'Ġmen', 'Ġand', 'Ġtheir', 'Ġspecific', 'Ġskating', 'Ġformation', 'Ġbut', 'Ġdoes', 'Ġnot', 'Ġmention', 'Ġtheir', 'Ġheight', '.', 'ĠSince', 'Ġthe', 'Ġhypothesis', 'Ġintroduces', 'Ġthe', 'Ġattribute', 'Ġof', 'Ġbeing', 'Ġtall', 'Ġwithout', 'Ġany', 'Ġsupporting', 'Ġevidence', 'Ġfrom', 'Ġthe', 'Ġpremise', ',', 'Ġthe', 'Ġrelationship', 'Ġis', 'Ġneither', 'Ġconfirmed', 'Ġnor', 'Ġcontradicted', '.']
#   Ġmen           : +0.1187
#   Ġmen           : +0.0514
# Token  1 'A              ': +0.0005
# Token  2 'Ġgroup         ': +0.0000
# Token  3 'Ġof            ': -0.0000
# Token  4 'Ġyoung         ': +0.0000
# Token  5 'Ġadults        ': +0.0002
# Token  6 'Ġwindow        ': +0.0131
# Token  7 'Ġshop          ': +0.0134
# Token  8 '.              ': +0.0002
# Token 11 'The            ': +0.0004
# Token 12 'Ġgroup         ': +0.0002
# Token 13 'Ġof            ': +0.0000
# Token 14 'Ġyoung         ': +0.0000
# Token 15 'Ġadults        ': +0.0001
# Token 16 'Ġmarch         ': +0.1480
# Token 17 'Ġin            ': +0.0002
# Token 18 'Ġthe           ': +0.0002
# Token 19 'Ġstreet        ': +0.0001
# Token 20 '.              ': +0.0000
#   Ġmarch         : +0.8369
#   Ġshop          : +0.0760
#   Ġwindow        : +0.0744
#   A              : +0.0029
#   The            : +0.0021
# ['Window', 'Ġshopping', 'Ġtypically', 'Ġinvolves', 'Ġcasually', 'Ġbrowsing', 'Ġstore', 'Ġdisplays', 'Ġwithout', 'Ġpurchasing', ',', 'Ġwhich', 'Ġimplies', 'Ġa', 'Ġstationary', 'Ġor', 'Ġslow', '-', 'paced', 'Ġactivity', '.', 'ĠMarch', 'ing', 'Ġin', 'Ġthe', 'Ġstreet', 'Ġsuggests', 'Ġorganized', ',', 'Ġpurpose', 'ful', 'Ġmovement', ',', 'Ġoften', 'Ġfor', 'Ġprotest', 'Ġor', 'Ġdemonstration', '.', 'ĠThese', 'Ġare', 'Ġincompatible', 'Ġactivities', ',', 'Ġmaking', 'Ġthe', 'Ġhypothesis', 'Ġa', 'Ġcontradiction', 'Ġof', 'Ġthe', 'Ġpremise', '.']
# Token  1 'An             ': -0.0000
# Token  2 'ĠAsian         ': +0.0001
# Token  3 'Ġman           ': +0.0000
# Token  4 'Ġis            ': +0.0000
# Token  5 'Ġstanding      ': +0.0002
# Token  6 'Ġon            ': +0.0001
# Token  7 'Ġa             ': +0.0000
# Token  8 'Ġbusy          ': +0.0005
# Token  9 'Ġsidewalk      ': +0.0007
# Token 10 'Ġas            ': +0.0000
# Token 11 'Ġpeople        ': +0.0000
# Token 12 'Ġwalk          ': +0.0000
# Token 13 'Ġby            ': +0.0000
# Token 14 'Ġwith          ': +0.0000
# Token 15 'Ġbags          ': +0.0000
# Token 16 '.              ': -0.0000
# Token 19 'The            ': -0.0000
# Token 20 'Ġman           ': +0.0003
# Token 21 'Ġis            ': +0.0000
# Token 22 'Ġin            ': +0.0012
# Token 23 'Ġthe           ': +0.0000
# Token 24 'Ġforest        ': +0.6841
# Token 25 '.              ': +0.0000
#   Ġforest        : +0.9950
#   Ġin            : +0.0017
#   Ġsidewalk      : +0.0011
#   Ġbusy          : +0.0007
#   Ġman           : +0.0005
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġbusy', 'Ġsidewalk', 'Ġwith', 'Ġpeople', 'Ġcarrying', 'Ġbags', ',', 'Ġwhich', 'Ġindicates', 'Ġan', 'Ġurban', 'Ġsetting', '.', 'ĠFore', 'sts', 'Ġdo', 'Ġnot', 'Ġhave', 'Ġsidewalks', 'Ġor', 'Ġbustling', 'Ġpedestrian', 'Ġactivity', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġthat', 'Ġthe', 'Ġman', 'Ġis', 'Ġin', 'Ġa', 'Ġforest', 'Ġdirectly', 'Ġcontradicts', 'Ġthe', 'Ġdescribed', 'Ġenvironment', '.']
#   Ġforest        : +0.9950
#   Ġin            : +0.0017
#   Ġsidewalk      : +0.0011
#   Ġbusy          : +0.0007
#   Ġman           : +0.0005
# Token  1 'A              ': +0.0920
# Token  2 'Ġdog           ': +0.0097
# Token  3 'Ġis            ': +0.1078
# Token  4 'Ġp             ': +0.0979
# Token  5 'lling          ': -0.0477
# Token  6 'Ġa             ': +0.0468
# Token  7 'Ġvery          ': -0.0144
# Token  8 'Ġlarge         ': -0.0042
# Token  9 'Ġbranch        ': -0.1325
# Token 10 'Ġout           ': -0.0474
# Token 11 'Ġof            ': -0.0599
# Token 12 'Ġthe           ': -0.0356
# Token 13 'Ġwater         ': -0.0215
# Token 14 '.              ': +0.0297
# Token 17 'An             ': -0.0281
# Token 18 'Ġanimal        ': -0.2672
# Token 19 'Ġis            ': -0.0784
# Token 20 'Ġdancing       ': +0.7158
# Token 21 '.              ': +0.1565
#   Ġdancing       : +0.3591
#   Ġanimal        : -0.1341
#   .              : +0.0785
#   Ġbranch        : -0.0665
#   Ġis            : +0.0541
# ['The', 'Ġpremise', 'Ġdescribes', 'Ġa', 'Ġdog', 'Ġperforming', 'Ġthe', 'Ġaction', 'Ġof', 'Ġpulling', 'Ġa', 'Ġbranch', ',', 'Ġwhich', 'Ġinvolves', 'Ġphysical', 'Ġeffort', 'Ġand', 'Ġmovement', '.', 'ĠDancing', 'Ġrequires', 'Ġa', 'Ġspecific', 'Ġtype', 'Ġof', 'Ġrhyth', 'mic', 'Ġmovement', 'Ġfor', 'Ġexpression', 'Ġor', 'Ġentertainment', ',', 'Ġwhich', 'Ġis', 'Ġnot', 'Ġsupported', 'Ġby', 'Ġthe', 'Ġdescribed', 'Ġaction', '.', 'ĠTherefore', ',', 'Ġthe', 'Ġhypothesis', 'Ġabout', 'Ġan', 'Ġanimal', 'Ġdancing', 'Ġcontradicts', 'Ġthe', 'Ġactivity', 'Ġin', 'Ġthe', 'Ġpremise', '.']
#   Ġdancing       : +0.3591
#   .              : +0.0785
#   Ġis            : +0.0541
# Done! CSV saved with results.

# %%
import pandas as pd

df_results = pd.read_csv("data/Results.csv")

# Show first few rows
print(df_results.head())

# General info
print(df_results.info())

# Summary statistics for numeric columns
print(df_results.describe())

metrics = ["prediction_confidence", "Faith_score", "Density_score", "Token_recall"]

for metric in metrics:
    print(f"\n--- {metric} ---")
    print(f"Mean: {df_results[metric].mean():.4f}")
    print(f"Median: {df_results[metric].median():.4f}")
    print(f"Min: {df_results[metric].min():.4f}")
    print(f"Max: {df_results[metric].max():.4f}")
    print(f"Standard Deviation: {df_results[metric].std():.4f}")

print("\nCorrelation between metrics:")
print(df_results[metrics].corr())

analysis = df_results[metrics].describe()
analysis.to_csv("data/Results_analysis.csv")
print("Saved statistical summary to Results_analysis.csv")
# Out:
#                                              premise  \
# 0      A woman in a blue apron cooking in a kitchen.
# 1  This young man smiles as he discovers a horses...
# 2  Three young boys playing with the mud on a beach.
# 3          A lock box on a pole with the keys in it.
# 4  A man pours water on plants in a vast field of...
#
#                                           hypothesis          label  \
# 0      A woman in a pink apron sitting in a kitchen.  contradiction
# 1     The young man is at school taking a math test.  contradiction
# 2                Three young girls are at the beach.  contradiction
# 3  A blue lock box  attached to the side of the h...  contradiction
# 4                                A man waters plants     entailment
#
#                                          explanation  predicted_label  \
# 0  The premise states the woman is wearing a blue...                0
# 1  The premise describes the young man discoverin...                0
# 2  The premise specifies the individuals are "you...                0
# 3  The premise describes a lock box on a pole, wh...                1
# 4  The premise states that a man pours water on p...                2
#
#    prediction_confidence  Faith_score  Density_score  Token_recall
# 0               0.998966     1.000000       0.019583           1.0
# 1               0.710824     0.553661       0.004983           0.6
# 2               0.999026     0.998477       0.025575           0.4
# 3               0.997055     0.019656       0.000413           0.6
# 4               0.986017     0.426622       0.006752           0.6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   premise                500 non-null    object
#  1   hypothesis             500 non-null    object
#  2   label                  500 non-null    object
#  3   explanation            500 non-null    object
#  4   predicted_label        500 non-null    int64
#  5   prediction_confidence  500 non-null    float64
#  6   Faith_score            500 non-null    float64
#  7   Density_score          500 non-null    float64
#  8   Token_recall           500 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 35.3+ KB
# None
#        predicted_label  prediction_confidence  Faith_score  Density_score  \
# count       500.000000             500.000000   500.000000     500.000000
# mean          1.040000               0.923786     0.776016       0.011719
# std           0.826902               0.126683     0.305082       0.006850
# min           0.000000               0.385899     0.000000       0.000000
# 25%           0.000000               0.915330     0.657801       0.006637
# 50%           1.000000               0.986942     0.932360       0.011831
# 75%           2.000000               0.996387     1.000000       0.016817
# max           2.000000               0.999524     1.000000       0.029378
#
#        Token_recall
# count    500.000000
# mean       0.732567
# std        0.258272
# min        0.000000
# 25%        0.600000
# 50%        0.800000
# 75%        1.000000
# max        1.000000
#
# --- prediction_confidence ---
# Mean: 0.9238
# Median: 0.9869
# Min: 0.3859
# Max: 0.9995
# Standard Deviation: 0.1267
#
# --- Faith_score ---
# Mean: 0.7760
# Median: 0.9324
# Min: 0.0000
# Max: 1.0000
# Standard Deviation: 0.3051
#
# --- Density_score ---
# Mean: 0.0117
# Median: 0.0118
# Min: 0.0000
# Max: 0.0294
# Standard Deviation: 0.0069
#
# --- Token_recall ---
# Mean: 0.7326
# Median: 0.8000
# Min: 0.0000
# Max: 1.0000
# Standard Deviation: 0.2583
#
# Correlation between metrics:
#                        prediction_confidence  Faith_score  Density_score  \
# prediction_confidence               1.000000     0.190548       0.444264
# Faith_score                         0.190548     1.000000       0.743855
# Density_score                       0.444264     0.743855       1.000000
# Token_recall                        0.123004     0.810957       0.523113
#
#                        Token_recall
# prediction_confidence      0.123004
# Faith_score                0.810957
# Density_score              0.523113
# Token_recall               1.000000
# Saved statistical summary to Results_analysis.csv
